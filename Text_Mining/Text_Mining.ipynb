# %% [markdown]
# Text Mining in Python

# %% [markdown]
# Text Mining is the process of deriving meaningful information from natural language text.
#
# Note: NLP is a component of text mining that performs a special kind of linguistic analysis that essentially helps a machine “read” text. It uses a different methodology to decipher the ambiguities in human language, including the following: automatic summarization, part-of-speech tagging, disambiguation, chunking, as well as disambiguation and natural language understanding and recognition.

# %% [markdown]
# Terminologies in NLP
# - Tokenization: Tokenization is the first step in NLP. It is the process of breaking strings into tokens which in turn are small structures or units. Tokenization involves three steps which are breaking a complex sentence into words, understanding the importance of each word with respect to the sentence and finally produce structural description on an input sentence.

# %%
# Importing necessary library
import pandas as pd
import numpy as np
import nltk
import os
import nltk.corpus

# %%
# Input the data (Open a text file for reading)
text = open('JD.txt', 'r')

# Store content in a variable
text = text.read()

# %%
# importing word_tokenize from nltk
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

# Pass the string text into word tokenize for breaking the sentences
token = word_tokenize(text)
token

# We can see the text split into tokens. Words, comma, punctuations are called tokens.
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['Data',
#  'Analyst',
#  '-',
#  'Geotab',
#  'Hiring',
#  'Manager',
#  '-',
#  'James',
#  'Brown',
#  'Location',
#  '-',
#  'Oakville',
#  'Who',
#  'we',
#  'are',
#  ':',
#  'Geotab',
#  'is',
#  'a',
#  'global',
#  'leader',
#  'in',
#  'IoT',
#  'and',
#  'connected',
#  'transportation',
#  'and',
#  'certified',
#  '“',
#  'Great',
#  'Place',
#  'to',
#  'Work.',
#  '”',
#  'We',
#  'are',
#  'a',
#  'company',
#  'of',
#  'diverse',
#  'and',
#  'talented',
#  'individuals',
#  'who',
#  'work',
#  'together',
#  'to',
#  'help',
#  'businesses',
#  'grow',
#  'and',
#  'succeed',
#  ',',
#  'and',
#  'increase',
#  'the',
#  'safety',
#  'and',
#  'sustainability',
#  'of',
#  'our',
#  'communities',
#  '.',
#  'Geotab',
#  'is',
#  'advancing',
#  'security',
#  ',',
#  'connecting',
#  'commercial',
#  'vehicles',
#  'to',
#  'the',
#  'internet',
#  'and',
#  'providing',
#  'web-based',
#  'analytics',
#  'to',
#  'help',
#  'customers',
#  'better',
#  'manage',
#  'their',
#  'fleets',
#  '.',
#  'Geotab',
#  '’',
#  's',
#  'open',
#  'platform',
#  'and',
#  'Marketplace',
#  ',',
#  'offering',
#  'hundreds',
#  'of',
#  'third-party',
#  'solution',
#  'options',
#  ',',
#  'allows',
#  'both',
#  'small',
#  'and',
#  'large',
#  'businesses',
#  'to',
#  'automate',
#  'operations',
#  'by',
#  'integrating',
#  'vehicle',
#  'data',
#  'with',
#  'their',
#  'other',
#  'data',
#  'assets',
#  '.',
#  'Processing',
#  'billions',
#  'of',
#  'data',
#  'points',
#  'a',
#  'day',
#  ',',
#  'Geotab',
#  'leverages',
#  'data',
#  'analytics',
#  'and',
#  'machine',
#  'learning',
#  'to',
#  'improve',
#  'productivity',
#  ',',
#  'optimize',
#  'fleets',
#  'through',
#  'the',
#  'reduction',
#  'of',
#  'fuel',
#  'consumption',
#  ',',
#  'enhance',
#  'driver',
#  'safety',
#  'and',
#  'achieve',
#  'strong',
#  'compliance',
#  'to',
#  'regulatory',
#  'changes',
#  '.',
#  'Our',
#  'team',
#  'is',
#  'growing',
#  'and',
#  'we',
#  '’',
#  're',
#  'looking',
#  'for',
#  'people',
#  'who',
#  'follow',
#  'their',
#  'passion',
#  ',',
#  'think',
#  'differently',
#  'and',
#  'want',
#  'to',
#  'make',
#  'an',
#  'impact',
#  '.',
#  'Join',
#  'us',
#  'for',
#  'a',
#  'fulfilling',
#  'career',
#  'with',
#  'opportunities',
#  'to',
#  'innovate',
#  ',',
#  'great',
#  'benefits',
#  ',',
#  'and',
#  'our',
#  'fun',
#  'and',
#  'inclusive',
#  'work',
#  'culture',
#  '.',
#  'Reach',
#  'your',
#  'full',
#  'potential',
#  'with',
#  'Geotab',
#  '.',
#  'To',
#  'see',
#  'what',
#  'it',
#  '’',
#  's',
#  'like',
#  'to',
#  'be',
#  'a',
#  'Geotabber',
#  ',',
#  'follow',
#  'us',
#  '@',
#  'InsideGeotab',
#  'on',
#  'Instagram',
#  ',',
#  'Twitter',
#  'or',
#  'Facebook',
#  '.',
#  'Who',
#  'we',
#  'are',
#  'looking',
#  'for',
#  ':',
#  'We',
#  'are',
#  'looking',
#  'for',
#  'Data',
#  'Analysts',
#  'who',
#  'can',
#  'help',
#  'us',
#  'discover',
#  'value',
#  'out',
#  'of',
#  'our',
#  'rich',
#  'and',
#  'large',
#  'datasets',
#  '.',
#  'Our',
#  'ideal',
#  'team',
#  'member',
#  'will',
#  'have',
#  'the',
#  'mathematical',
#  'and',
#  'statistical',
#  'expertise',
#  'you',
#  '’',
#  'd',
#  'expect',
#  ',',
#  'but',
#  'a',
#  'natural',
#  'curiosity',
#  'and',
#  'creative',
#  'mind',
#  'that',
#  '’',
#  's',
#  'not',
#  'so',
#  'easy',
#  'to',
#  'find',
#  '.',
#  'As',
#  'you',
#  'mine',
#  ',',
#  'interpret',
#  'and',
#  'clean',
#  'our',
#  'data',
#  ',',
#  'we',
#  'will',
#  'rely',
#  'on',
#  'you',
#  'to',
#  'ask',
#  'questions',
#  ',',
#  'connect',
#  'the',
#  'dots',
#  'and',
#  'uncover',
#  'opportunities',
#  'that',
#  'lie',
#  'hidden',
#  'within',
#  ',',
#  'all',
#  'with',
#  'the',
#  'ultimate',
#  'goal',
#  'of',
#  'realizing',
#  'the',
#  'data',
#  '’',
#  's',
#  'full',
#  'potential',
#  '.',
#  'What',
#  'are',
#  'the',
#  'details',
#  'of',
#  'this',
#  'position',
#  ':',
#  'The',
#  'Data',
#  'Analyst',
#  'will',
#  'join',
#  'RMA',
#  'team',
#  'under',
#  'Operations',
#  'and',
#  'will',
#  'analyze',
#  'well-defined',
#  'sets',
#  'of',
#  'data',
#  'using',
#  'a',
#  'variety',
#  'of',
#  'different',
#  'tools',
#  'to',
#  'answer',
#  'tangible',
#  'business',
#  'needs',
#  'and',
#  'find',
#  'meaningful',
#  'insights',
#  '.',
#  'The',
#  'position',
#  'will',
#  'understand',
#  'how',
#  'internal',
#  'departments',
#  'can',
#  'directly',
#  'benefit',
#  'from',
#  'the',
#  'analysis',
#  'and',
#  'develop',
#  'products',
#  'from',
#  'these',
#  'results',
#  '.',
#  'The',
#  'position',
#  'works',
#  'closely',
#  'with',
#  'Data',
#  'professionals',
#  'within',
#  'the',
#  'Data',
#  '&',
#  'Analytics',
#  'Teams',
#  '.',
#  'Duties',
#  'and',
#  'Tasks/Essential',
#  'Functions',
#  ':',
#  'Examine',
#  'large',
#  'data',
#  'sets',
#  'to',
#  'identify',
#  'trends',
#  ',',
#  'develop',
#  'charts',
#  ',',
#  'and',
#  'creative',
#  'visual',
#  'presentations',
#  'to',
#  'help',
#  'businesses',
#  'make',
#  'more',
#  'strategic',
#  'decisions',
#  '.',
#  'Maintain',
#  'data',
#  'systems',
#  'and',
#  'databases',
#  '.',
#  'Utilize',
#  'statistical',
#  'tools',
#  'to',
#  'interpret',
#  'data',
#  'sets',
#  'and',
#  'prepare',
#  'reports',
#  'that',
#  'effectively',
#  'communicate',
#  'trends',
#  ',',
#  'patterns',
#  ',',
#  'and',
#  'predictions',
#  'based',
#  'on',
#  'relevant',
#  'findings',
#  '.',
#  'Write',
#  'SQL',
#  'queries',
#  'to',
#  'find',
#  'answers',
#  'to',
#  'complex',
#  'business',
#  'questions',
#  '.',
#  'Identify',
#  'any',
#  'data',
#  'quality',
#  'issues',
#  'and',
#  'partialities',
#  'in',
#  'data',
#  'acquisition',
#  '.',
#  'Coordinate',
#  'with',
#  'the',
#  'engineering',
#  'team',
#  'to',
#  'gather',
#  'incremental',
#  'new',
#  'data',
#  '.',
#  'Process',
#  ',',
#  'cleanse',
#  'and',
#  'verify',
#  'the',
#  'integrity',
#  'of',
#  'data',
#  'used',
#  'for',
#  'analysis',
#  '.',
#  'Use',
#  'data',
#  'mining',
#  ',',
#  'model',
#  'building',
#  ',',
#  'and',
#  'other',
#  'analytical',
#  'techniques',
#  'to',
#  'support',
#  'internal',
#  'initiatives',
#  '.',
#  'Assist',
#  'the',
#  'internal',
#  'technical',
#  'departments',
#  'by',
#  'providing',
#  'meaningful',
#  'insight',
#  'using',
#  'datasets',
#  '.',
#  'Work',
#  'with',
#  'data',
#  'scientists',
#  'and',
#  'leverage',
#  'machine',
#  'learning',
#  'models',
#  'that',
#  'have',
#  'been',
#  'developed',
#  'against',
#  'Geotab',
#  "'s",
#  'big',
#  'data',
#  'environment',
#  '.',
#  'Experience/Skills',
#  'Required',
#  ':',
#  '0-5',
#  'years',
#  'experience',
#  'as',
#  'a',
#  'Data',
#  'Analyst',
#  'or',
#  'a',
#  'similar',
#  'role',
#  '.',
#  '3-5',
#  'years',
#  'experience',
#  'with',
#  'SQL',
#  '.',
#  '3-5',
#  'years',
#  'experience',
#  'with',
#  'data',
#  'science',
#  'tools',
#  '(',
#  'e.g',
#  'Python',
#  ',',
#  'Pandas',
#  ',',
#  'NumPy',
#  ')',
#  '.',
#  'Post-secondary',
#  'Degree/Diploma',
#  'specialization',
#  'in',
#  'Computer',
#  'Science',
#  ',',
#  'Software',
#  'Engineering',
#  ',',
#  'Science',
#  ',',
#  'Mathematics',
#  'or',
#  'a',
#  'related',
#  'field',
#  '.',
#  'Experience',
#  'working',
#  'with',
#  'big',
#  'data',
#  'and',
#  'an',
#  'understanding',
#  'of',
#  'techniques',
#  'used',
#  'to',
#  'extract',
#  'value',
#  'out',
#  'of',
#  'very',
#  'large',
#  'datasets',
#  '.',
#  'Experience',
#  'working',
#  'closely',
#  'with',
#  'business',
#  'analysts',
#  'to',
#  'arrive',
#  'at',
#  'data',
#  'solutions',
#  '.',
#  'Experience',
#  'with',
#  'database',
#  'design',
#  'and',
#  'writing',
#  'queries',
#  '.',
#  'Familiarity',
#  'with',
#  'machine',
#  'learning',
#  'concepts',
#  'is',
#  'an',
#  'asset',
#  '.',
#  'Familiarity',
#  'with',
#  'Scikit-learn',
#  ',',
#  'Tensorflow',
#  'is',
#  'an',
#  'asset',
#  '.',
#  'Why',
#  'job',
#  'seekers',
#  'choose',
#  'Geotab',
#  ':',
#  'Work',
#  'from',
#  'home',
#  'and',
#  'flex',
#  'work',
#  'arrangements',
#  'Baby',
#  'bonus',
#  'Home',
#  'office',
#  'reimbursement',
#  'program',
#  'Online',
#  'learning',
#  'and',
#  'networking',
#  'opportunities',
#  'Electric',
#  'vehicle',
#  'purchase',
#  'incentive',
#  'program',
#  'Competitive',
#  'medical',
#  'and',
#  'dental',
#  'benefits',
#  '(',
#  'full-time',
#  'employees',
#  'only',
#  ')',
#  'Retirement',
#  'savings',
#  'program',
#  '(',
#  'full-time',
#  'employees',
#  'only',
#  ')',
#  'Our',
#  'Core',
#  'Values',
#  ':',
#  'At',
#  'Geotab',
#  ',',
#  'we',
#  'understand',
#  'that',
#  'the',
#  'world',
#  'is',
#  'always',
#  'changing',
#  'and',
#  'that',
#  'we',
#  'need',
#  'to',
#  'change',
#  'with',
#  'it',
#  '.',
#  'Geotab',
#  'has',
#  'adopted',
#  'a',
#  'hybrid',
#  'model',
#  'for',
#  'working',
#  ',',
#  'including',
#  'a',
#  'flexible',
#  'work',
#  'from',
#  'home',
#  'program',
#  ',',
#  'with',
#  'the',
#  'opportunity',
#  'to',
#  'work',
#  'in',
#  'our',
#  'safe',
#  ',',
#  'clean',
#  'offices',
#  '.',
#  'Remote',
#  'work',
#  'is',
#  'supported',
#  'with',
#  'cloud-based',
#  'applications',
#  ',',
#  'collaboration',
#  'tools',
#  'and',
#  'asynchronous',
#  'working',
#  '.',
#  'The',
#  'health',
#  'and',
#  'safety',
#  'of',
#  'employees',
#  'are',
#  'a',
#  'top',
#  'priority',
#  '.',
#  'We',
#  'encourage',
#  'work-life',
#  'balance',
#  'and',
#  'keep',
#  'the',
#  'Geotab',
#  'culture',
#  'going',
#  'strong',
#  'with',
#  'online',
#  'social',
#  'events',
#  ',',
#  'chat',
#  'rooms',
#  'and',
#  'gatherings',
#  '.',
#  'Join',
#  'us',
#  'and',
#  'help',
#  'reshape',
#  'the',
#  'future',
#  'of',
#  'technology',
#  '!',
#  'Data',
#  'Analyst',
#  '-',
#  'Dialpad',
#  'Hiring',
#  'Manager',
#  '-',
#  'Chris',
#  'Yellow',
#  'Location',
#  '-',
#  'Toronto',
#  'Dialpad',
#  'is',
#  'the',
#  'most',
#  'modern',
#  'business',
#  'communications',
#  'company',
#  'in',
#  'the',
#  'industry',
#  '.',
#  'Our',
#  'products',
#  'range',
#  'from',
#  'conference',
#  'calling',
#  ',',
#  'to',
#  'phone',
#  'systems',
#  'to',
#  'contact',
#  'center',
#  'solutions',
#  'that',
#  'are',
#  'all',
#  'built',
#  'with',
#  'the',
#  'end-user',
#  'in',
#  'mind',
#  '.',
#  'We',
#  'allow',
#  'workers',
#  'to',
#  'be',
#  'productive',
#  'from',
#  'anywhere',
#  'on',
#  'any',
#  'device',
#  'and',
#  'have',
#  'moved',
#  'all',
#  'the',
#  'power',
#  'of',
#  'an',
#  'on-premise',
#  'phone',
#  'system',
#  'or',
#  'contact',
#  'center',
#  'to',
#  'the',
#  'cloud',
#  'to',
#  'be',
#  'accessed',
#  'and',
#  'used',
#  'by',
#  'modern',
#  'workers',
#  'in',
#  'today',
#  "'s",
#  'Work',
#  'from',
#  'Anywhere',
#  'environment',
#  '.',
#  'Who',
#  'We',
#  'Are',
#  'At',
#  'Dialpad',
#  ',',
#  'work',
#  'is',
#  "n't",
#  'a',
#  'place',
#  'you',
#  'go',
#  ',',
#  'it',
#  "'s",
#  'a',
#  'thing',
#  'you',
#  'do',
#  '.',
#  'With',
#  'offices',
#  'in',
#  'San',
#  'Francisco',
#  ',',
#  'San',
#  'Ramon',
#  ',',
#  'Austin',
#  ',',
#  'Raleigh',
#  ',',
#  'Vancouver',
#  ',',
#  'Waterloo',
#  ',',
#  'Tokyo',
#  ',',
#  'London',
#  ',',
#  'Sydney',
#  'and',
#  'Bangalore',
#  ',',
#  'we',
#  'truly',
#  'believe',
#  'in',
#  'finding',
#  'the',
#  'best',
#  'talent',
#  'everywhere',
#  '.',
#  'We',
#  'also',
#  'embrace',
#  'the',
#  'Work',
#  'from',
#  'Home',
#  'movement',
#  'and',
#  'are',
#  'just',
#  'as',
#  'happy',
#  'hiring',
#  'great',
#  'talent',
#  'from',
#  'anywhere',
#  'if',
#  ...]

# %% [markdown]
# Finding frequency distinct in the text

# %%
# Finding the frequency distinct in the tokens (importing FreqDist library from nltk and passing token into FreqDist)

from nltk.probability import FreqDist
fdist = FreqDist(token)
fdist
# Out:
# FreqDist({'!': 4,
#           '$': 1,
#           '%': 1,
#           '&': 3,
#           "'": 1,
#           "'d": 1,
#           "'re": 3,
#           "'s": 5,
#           '(': 7,
#           ')': 7,
#           ',': 124,
#           '-': 12,
#           '.': 86,
#           '0-5': 1,
#           '100': 1,
#           '220': 1,
#           '3': 1,
#           '3+': 1,
#           '3-5': 2,
#           ':': 14,
#           ';': 1,
#           '<': 8,
#           '>': 8,
#           '?': 1,
#           '@': 2,
#           'A': 1,
#           'AI': 2,
#           'ASR': 1,
#           'AWS': 1,
#           'Ability': 2,
#           'About': 2,
#           'Advanced': 1,
#           'All': 1,
#           'An': 1,
#           'Analyst': 9,
#           'Analysts': 1,
#           'Analytics': 1,
#           'Andreessen': 1,
#           'Anywhere': 1,
#           'Are': 1,
#           'Argentine': 1,
#           'As': 2,
#           'Assist': 1,
#           'At': 2,
#           'Austin': 2,
#           'B2B': 1,
#           'BS': 1,
#           'Baby': 1,
#           'Bangalore': 2,
#           'Because': 1,
#           'Bonus': 1,
#           'Brown': 1,
#           'Build': 1,
#           'Canada': 2,
#           'Capital': 1,
#           'Chris': 1,
#           'Communicate': 1,
#           'Compensation': 1,
#           'Competitive': 1,
#           'Computer': 2,
#           'Conditions': 1,
#           'Coordinate': 1,
#           'Core': 1,
#           'Coursework': 1,
#           'Data': 15,
#           'Degree/Diploma': 1,
#           'Design': 1,
#           'Dialpad': 5,
#           'Duties': 1,
#           'ETL': 1,
#           'Education': 1,
#           'Electric': 1,
#           'Employment': 1,
#           'Engineering': 2,
#           'Equity': 2,
#           'Examine': 1,
#           'Excellent': 2,
#           'Experience': 9,
#           'Experience/Skills': 1,
#           'Expertise': 1,
#           'Facebook': 1,
#           'Familiarity': 2,
#           'Felicis': 1,
#           'Flexible': 1,
#           'Francisco': 2,
#           'From': 1,
#           'Functions': 1,
#           'GV': 1,
#           'Geotab': 13,
#           'Geotabber': 1,
#           'Given': 1,
#           'Google': 1,
#           'Great': 1,
#           'Growth': 1,
#           'Healthcare': 1,
#           'Hiring': 3,
#           'History': 1,
#           'Home': 2,
#           'Horowitz': 1,
#           'ICONIQ': 1,
#           'Ideally': 1,
#           'Identify': 1,
#           'If': 3,
#           'In': 1,
#           'Indigenous': 1,
#           'Information': 1,
#           'InsideGeotab': 1,
#           'Instagram': 1,
#           'Intelligence': 1,
#           'IoT': 1,
#           'James': 1,
#           'John': 1,
#           'Join': 2,
#           'Joining': 1,
#           'Kitchener': 1,
#           'Labs': 1,
#           'Language': 2,
#           'Linguistics': 1,
#           'Location': 6,
#           'London': 1,
#           'MB': 1,
#           'Maintain': 1,
#           'Management': 1,
#           'Manager': 3,
#           'Marketplace': 1,
#           'Mathematics': 2,
#           'Microsoft': 1,
#           'Must': 1,
#           'Natural': 2,
#           'New': 1,
#           'NumPy': 1,
#           'OMERS': 1,
#           'Oakville': 1,
#           'Online': 1,
#           'Operations': 1,
#           'Our': 4,
#           'Pandas': 1,
#           'Partner': 1,
#           'Place': 1,
#           'Post-secondary': 1,
#           'Private': 2,
#           'Process': 1,
#           'Processing': 3,
#           'Provide': 1,
#           'Python': 2,
#           'Python/pandas': 1,
#           'R': 1,
#           'RMA': 1,
#           'Raleigh': 2,
#           'Ramon': 2,
#           'Reach': 1,
#           'Recognition': 2,
#           'Reimbursements': 1,
#           'Remote': 1,
#           'Required': 1,
#           'Requirements': 1,
#           'Responsibilities': 1,
#           'Retirement': 1,
#           'Role': 1,
#           'SQL': 4,
#           'San': 4,
#           'Scale': 1,
#           'Science': 5,
#           'Scikit-learn': 1,
#           'Software': 1,
#           'Sound': 1,
#           'Speech': 3,
#           'Start': 1,
#           'Stata': 1,
#           'Statistics': 2,
#           'Sydney': 1,
#           'Tasks/Essential': 1,
#           'Teams': 1,
#           'Teamwork': 1,
#           'Tensorflow': 1,
#           'That': 2,
#           'The': 9,
#           'There': 1,
#           'To': 1,
#           'Tokyo': 2,
#           'Toronto': 1,
#           'Twitter': 1,
#           'Us': 1,
#           'Use': 1,
#           'Utilize': 1,
#           'VCs': 1,
#           'Values': 1,
#           'Vancouver': 2,
#           'Ventures': 2,
#           'Voice': 1,
#           'Water': 1,
#           'Waterloo': 1,
#           'We': 10,
#           'Wealth': 2,
#           'Wellington': 1,
#           'Wellington-Altus': 3,
#           'What': 1,
#           'Who': 3,
#           'Why': 1,
#           'Winnipeg': 2,
#           'With': 2,
#           'Work': 4,
#           'Work-Bench': 1,
#           'Work.': 1,
#           'Write': 2,
#           'Yellow': 1,
#           'York': 1,
#           'You': 2,
#           'Your': 1,
#           'a': 32,
#           'ability': 1,
#           'able': 1,
#           'about': 4,
#           'accessed': 1,
#           'accommodating': 1,
#           'accommodation': 3,
#           'achieve': 1,
#           'acquisition': 1,
#           'across': 2,
#           'actionable': 2,
#           'active': 1,
#           'ad': 1,
#           'addition': 1,
#           'address': 1,
#           'administration': 2,
#           'adopted': 1,
#           'advancing': 1,
#           'against': 1,
#           'agile': 1,
#           'all': 7,
#           'allow': 1,
#           'allows': 1,
#           'also': 1,
#           'always': 1,
#           'an': 12,
#           'analysis': 4,
#           'analyst': 3,
#           'analysts': 1,
#           'analytical': 2,
#           'analytics': 2,
#           'analyze': 1,
#           'and': 101,
#           'another': 1,
#           'answer': 2,
#           'answers': 1,
#           'any': 3,
#           'anywhere': 3,
#           'apple': 1,
#           'applicant': 1,
#           'application': 2,
#           'applications': 4,
#           'apply': 1,
#           'are': 14,
#           'areas': 2,
#           'arrangements': 1,
#           'arrive': 1,
#           'as': 7,
#           'ask': 1,
#           'asking': 1,
#           'asset': 2,
#           'assets': 1,
#           'asynchronous': 1,
#           'at': 4,
#           'attention': 1,
#           'attracts': 1,
#           'automate': 2,
#           'away': 1,
#           'awesome': 1,
#           'background': 1,
#           'balance': 1,
#           'based': 1,
#           'basis': 1,
#           'be': 9,
#           'been': 1,
#           'believe': 3,
#           'benefit': 1,
#           'benefits': 2,
#           'best': 1,
#           'better': 1,
#           'between': 1,
#           'bias': 1,
#           'big': 2,
#           'billions': 1,
#           'bonus': 1,
#           'books': 1,
#           'both': 1,
#           'bringing': 1,
#           'building': 3,
#           'built': 1,
#           'burritos': 1,
#           'business': 9,
#           'businesses': 3,
#           'but': 2,
#           'by': 5,
#           'calling': 1,
#           'can': 7,
#           'candidates': 1,
#           'career': 1,
#           'careers': 1,
#           'cell': 1,
#           'center': 2,
#           'certified': 1,
#           'change': 1,
#           'changes': 1,
#           'changing': 2,
#           'charts': 1,
#           'chat': 1,
#           'check': 1,
#           'choose': 2,
#           'clean': 2,
#           'cleanse': 1,
#           'closely': 4,
#           'cloud': 1,
#           'cloud-based': 1,
#           'coast': 2,
#           'collaborate': 1,
#           'collaborating': 1,
#           'collaboration': 1,
#           'collection': 1,
#           'collections': 1,
#           'comfortable': 1,
#           'comic': 1,
#           'commencing': 1,
#           'commercial': 1,
#           'committed': 2,
#           'communicate': 1,
#           'communications': 1,
#           'communicator': 1,
#           'communities': 1,
#           'community': 2,
#           'companies': 1,
#           'company': 2,
#           'competitive': 1,
#           'complex': 1,
#           'compliance': 1,
#           'computing': 1,
#           'concepts': 1,
#           'conference': 1,
#           'connect': 1,
#           'connected': 1,
#           'connecting': 1,
#           'consumption': 1,
#           'contact': 3,
#           'continued': 1,
#           'contribute': 1,
#           'conversations': 1,
#           'costs': 1,
#           'cover': 1,
#           'crazy': 1,
#           'creating': 2,
#           'creative': 3,
#           'critical': 1,
#           'culture': 2,
#           'curiosity': 1,
#           'currently': 1,
#           'customer': 1,
#           'customers': 2,
#           'd': 1,
#           'data': 39,
#           'database': 2,
#           'databases': 1,
#           'datasets': 4,
#           'day': 2,
#           'decision-making': 1,
#           'decisions': 1,
#           'dedicated': 1,
#           'deeply': 1,
#           'degree': 1,
#           'deliver': 2,
#           'delivering': 1,
#           'dental': 2,
#           'departments': 2,
#           'design': 2,
#           'designing': 1,
#           'designs': 1,
#           'desire': 1,
#           'detail': 1,
#           'details': 1,
#           'develop': 2,
#           'developed': 1,
#           'device': 1,
#           'different': 2,
#           'differently': 1,
#           'directly': 1,
#           'disabilities': 2,
#           'discover': 1,
#           'discrimination': 1,
#           'diverse': 1,
#           'diversification': 1,
#           'diversity': 1,
#           'do': 4,
#           'doctor': 1,
#           'document': 1,
#           'documents': 2,
#           'does': 2,
#           'dots': 1,
#           'downtown': 1,
#           'dream': 1,
#           'driver': 1,
#           'dynamic': 1,
#           'e.g': 1,
#           'easy': 1,
#           'education': 2,
#           'effectively': 1,
#           'eligible': 1,
#           'embrace': 1,
#           'employees': 4,
#           'employer': 2,
#           'employment': 2,
#           'enable': 1,
#           'encourage': 1,
#           'encouraged': 1,
#           'encourages': 1,
#           'end-user': 1,
#           'engineering': 2,
#           'engineers': 2,
#           'enhance': 1,
#           'environment': 4,
#           'equal': 1,
#           'equity': 1,
#           'essential': 1,
#           'etc.': 1,
#           'even': 1,
#           'events': 1,
#           'every': 1,
#           'everywhere': 1,
#           'excellent': 1,
#           'existing': 1,
#           'expect': 1,
#           'expenses': 1,
#           'experience': 9,
#           'experimental': 1,
#           'expertise': 1,
#           'exploration': 1,
#           'extract': 2,
#           'field': 1,
#           'find': 3,
#           'finding': 1,
#           'findings': 1,
#           'fleets': 2,
#           'flex': 1,
#           'flexible': 1,
#           'follow': 2,
#           'for': 18,
#           'formulate': 1,
#           'frame': 1,
#           'free': 1,
#           'from': 19,
#           'fuel': 1,
#           'fulfilling': 1,
#           'full': 2,
#           'full-time': 2,
#           'fun': 1,
#           'funding': 1,
#           'further': 1,
#           'future': 3,
#           'gap': 1,
#           'gather': 1,
#           'gatherings': 1,
#           'genders': 1,
#           'generally': 1,
#           'generate': 1,
#           'geotab.com': 1,
#           'global': 1,
#           'go': 1,
#           'goal': 1,
#           'going': 2,
#           'great': 2,
#           'group': 1,
#           'grow': 1,
#           'growing': 3,
#           'gym': 1,
#           'handle': 1,
#           'happy': 1,
#           'harassment': 1,
#           'has': 2,
#           'have': 5,
#           'health': 1,
#           'hear': 1,
#           'help': 10,
#           'hidden': 1,
#           'hiring': 1,
#           'hoc': 1,
#           'home': 4,
#           'how': 2,
#           'huge': 1,
#           'hundreds': 1,
#           'hungry': 1,
#           'hurt': 1,
#           'hybrid': 1,
#           'hypothesis': 1,
#           'idea': 1,
#           'ideal': 2,
#           'identify': 2,
#           'if': 2,
#           'impact': 1,
#           'impactful': 1,
#           'improve': 3,
#           'in': 29,
#           'incentive': 1,
#           'include': 1,
#           'including': 2,
#           'inclusion': 1,
#           'inclusive': 1,
#           'increase': 1,
#           'incremental': 1,
#           'independently': 1,
#           'individuals': 2,
#           'industry': 1,
#           'information': 1,
#           'initiatives': 1,
#           'innovate': 1,
#           'innovation': 1,
#           'insight': 1,
#           'insightful': 1,
#           'insights': 5,
#           'inspired': 1,
#           'integrating': 1,
#           'integrity': 1,
#           'intelligence': 1,
#           'interesting': 2,
#           'internal': 3,
#           'internet': 2,
#           'interpret': 2,
#           'interview': 1,
#           'into': 2,
#           'is': 17,
#           'issues': 1,
#           'it': 6,
#           'its': 1,
#           'job': 1,
#           'join': 1,
#           'just': 2,
#           'keep': 1,
#           'keeps': 1,
#           'key': 1,
#           'know': 1,
#           'knowledge': 1,
#           'language': 2,
#           'large': 6,
#           'leader': 1,
#           'learning': 7,
#           'legally': 1,
#           'let': 1,
#           'leverage': 1,
#           'leverages': 1,
#           'lie': 1,
#           'like': 3,
#           'linguists': 1,
#           'listener': 1,
#           'load': 1,
#           'locations': 1,
#           'looking': 4,
#           'love': 1,
#           'machine': 5,
#           'maintain': 1,
#           'make': 4,
#           'makes': 1,
#           'manage': 2,
#           'manipulating': 1,
#           'mathematical': 1,
#           'may': 1,
#           'meaningful': 2,
#           'means': 1,
#           'medical': 2,
#           'member': 2,
#           'members': 1,
#           'membership': 1,
#           'million': 1,
#           'mind': 2,
#           'mine': 1,
#           'mining': 1,
#           'mix': 1,
#           'model': 2,
#           'modeling': 2,
#           'models': 4,
#           'modern': 2,
#           'monthly': 1,
#           'more': 5,
#           'most': 1,
#           'moved': 1,
#           'movement': 1,
#           'much': 1,
#           'multiple': 1,
#           'musicals': 1,
#           "n't": 3,
#           'name': 1,
#           'natural': 1,
#           'need': 2,
#           'needing': 1,
#           'needs': 3,
#           'nestled': 1,
#           'networking': 1,
#           'new': 2,
#           'no': 2,
#           'non-technical': 1,
#           'not': 1,
#           'of': 35,
#           'offer': 4,
#           'offering': 1,
#           'office': 2,
#           'offices': 3,
#           'on': 7,
#           'on-premise': 1,
#           'online': 1,
#           'only': 2,
#           'open': 1,
#           'operating': 1,
#           'operations': 3,
#           'opportunities': 4,
#           'opportunity': 2,
#           'optimize': 1,
#           'options': 2,
#           'or': 13,
#           'organization': 2,
#           'organizational': 1,
#           'orientations': 1,
#           'other': 4,
#           'our': 17,
#           'out': 2,
#           'over': 1,
#           'paid': 1,
#           'partialities': 1,
#           'passion': 1,
#           'passionate': 1,
#           'patterns': 1,
#           'people': 3,
#           'peoples': 1,
#           'person': 1,
#           'persons': 4,
#           'phone': 3,
#           'pipelines': 1,
#           'place': 1,
#           'plans': 1,
#           'platform': 1,
#           'plays': 1,
#           'please': 2,
#           'plus': 1,
#           'point': 2,
#           'points': 2,
#           'policies': 2,
#           'position': 4,
#           'potential': 2,
#           'power': 2,
#           'practices': 2,
#           'predictions': 1,
#           'prepare': 1,
#           'presentations': 1,
#           'prior': 1,
#           'priorities': 1,
#           'prioritize': 1,
#           'priority': 1,
#           'problem': 1,
#           'problems': 1,
#           'process': 4,
#           'processes': 2,
#           'product': 1,
#           'productive': 2,
#           'productivity': 1,
#           'products': 3,
#           'professionals': 1,
#           'program': 4,
#           'programs': 1,
#           'projects': 2,
#           'proof-of-concept': 1,
#           'proud': 1,
#           'provide': 1,
#           'providing': 2,
#           'purchase': 1,
#           'qualifications': 1,
#           'qualified': 2,
#           'quality': 1,
#           'quantitative': 1,
#           'queries': 3,
#           'question': 1,
#           'questions': 5,
#           'quo': 1,
#           'racialized': 1,
#           'range': 1,
#           'rather': 1,
#           're': 1,
#           'realizing': 1,
#           'recognize': 1,
#           'recommend': 1,
#           'recruiting': 1,
#           'recruitment': 1,
#           'redefine': 1,
#           'reduce': 1,
#           'reduction': 1,
#           'regard': 1,
#           'regular': 1,
#           'regulatory': 1,
#           'reimbursement': 1,
#           'related': 1,
#           'relevant': 1,
#           'rely': 1,
#           'reports': 1,
#           'require': 2,
#           'required': 2,
#           'requirements': 3,
#           'research': 2,
#           'reshape': 1,
#           'responsible': 1,
#           'results': 2,
#           'review': 2,
#           'rich': 1,
#           'right': 1,
#           'role': 5,
#           'rooms': 1,
#           'run': 1,
#           's': 4,
#           'safe': 1,
#           'safety': 3,
#           'salaries': 1,
#           'sales': 1,
#           'satisfactory': 1,
#           'savings': 1,
#           'scenarios': 1,
#           'science': 1,
#           'scientists': 3,
#           'scripting': 1,
#           'security': 1,
#           'see': 2,
#           'seekers': 1,
#           'selection': 1,
#           'sets': 6,
#           'sexual': 1,
#           'significance': 1,
#           'similar': 3,
#           'simplify': 1,
#           'skills': 3,
#           'small': 2,
#           'smart': 1,
#           'so': 1,
#           'social': 1,
#           'solution': 1,
#           'solutions': 5,
#           'some': 1,
#           'source': 1,
#           'specialization': 1,
#           'speech/language': 1,
#           'stage': 1,
#           'stakeholders': 4,
#           'standards': 1,
#           'started': 1,
#           'statistical': 4,
#           'status': 1,
#           'stipend': 2,
#           'stock': 1,
#           'stories': 1,
#           'strategic': 1,
#           'strong': 2,
#           'strongly': 1,
#           'structures': 1,
#           'succeed': 1,
#           'successful': 2,
#           'support': 7,
#           'supported': 1,
#           'sushi': 1,
#           'sustainability': 1,
#           'system': 1,
#           'systems': 4,
#           'take': 1,
#           'talent': 2,
#           'talented': 2,
#           'tangible': 1,
#           'tango': 1,
#           'task': 1,
#           'team': 11,
#           'teams': 3,
#           'technical': 4,
#           'techniques': 2,
#           'technology': 2,
#           'tell': 1,
#           'test': 1,
#           'testing': 1,
#           'than': 2,
#           'that': 14,
#           'the': 45,
#           'their': 5,
#           'them': 1,
#           'then': 1,
#           'these': 1,
#           'they': 2,
#           'thing': 1,
#           'things': 1,
#           'think': 1,
#           'thinking': 1,
#           'third-party': 1,
#           'this': 3,
#           'through': 1,
#           'throughout': 1,
#           'to': 66,
#           'today': 1,
#           'together': 3,
#           'told': 1,
#           'too': 2,
#           'tools': 4,
#           'top': 3,
#           'transcription': 1,
#           'transcriptions': 1,
#           'transform': 1,
#           'transportation': 1,
#           'trends': 3,
#           'truly': 1,
#           'turn': 2,
#           'ultimate': 1,
#           'uncover': 1,
#           'under': 1,
#           'understand': 4,
#           'understanding': 1,
#           'unlock': 2,
#           'us': 8,
#           'use-case': 1,
#           'used': 4,
#           'users': 1,
#           'using': 3,
#           'valuable': 1,
#           'value': 2,
#           'variety': 1,
#           'vehicle': 2,
#           'vehicles': 1,
#           'vendor': 1,
#           'verify': 1,
#           'very': 1,
#           'view': 1,
#           'views': 1,
#           'vision': 1,
#           'visual': 1,
#           'want': 2,
#           'ways': 1,
#           'we': 17,
#           'web-based': 1,
#           'welcomes': 1,
#           'well': 1,
#           'well-defined': 1,
#           'what': 3,
#           'where': 2,
#           'who': 5,
#           'why': 2,
#           'will': 12,
#           'with': 35,
#           'within': 3,
#           'women': 1,
#           'work': 20,
#           'work-life': 1,
#           'workers': 3,
#           'working': 6,
#           'works': 1,
#           'world': 1,
#           'would': 1,
#           'write': 1,
#           'writing': 1,
#           'yearly': 1,
#           'years': 5,
#           'you': 17,
#           'your': 3,
#           '—': 1,
#           '’': 6,
#           '“': 1,
#           '”': 1})

# %%
# To find the frequency of top 10 words

fdist1 = fdist.most_common(10)
fdist1
# Out:
# [(',', 124),
#  ('and', 101),
#  ('.', 86),
#  ('to', 66),
#  ('the', 45),
#  ('data', 39),
#  ('of', 35),
#  ('with', 35),
#  ('a', 32),
#  ('in', 29)]

# %% [markdown]
# Stemming: Stemming usually refers to normalizing words into its base form or root form.
#
# - There are two methods in Stemming namely, Porter Stemming (removes common morphological and inflectional endings from words) and Lancaster Stemming (a more aggressive stemming algorithm).

# %%
# Importing Porterstemmer from nltk library (checking for the word ‘giving’) 

from nltk.stem import PorterStemmer
pst = PorterStemmer()
pst.stem("waiting")
# Out:
# 'wait'

# %%
# Checking for the list of words

stm = ["waited", "waiting", "waits"]
for word in stm :
  print(word+ ":" +pst.stem(word))
# Out:
# waited:wait
# waiting:wait
# waits:wait

# %%
# Importing LancasterStemmer from nltk

from nltk.stem import LancasterStemmer
lst = LancasterStemmer()
stm = ["giving", "given", "given", "gave"]
for word in stm :
  print(word+ ":" +lst.stem(word))
# Out:
# giving:giv
# given:giv
# given:giv
# gave:gav

# %% [markdown]
# Lemmatization: It is the process of converting a word to its base form. The difference between stemming and lemmatization is, lemmatization considers the context and converts the word to its meaningful base form, whereas stemming just removes the last few characters, often leading to incorrect meanings and spelling errors.
#
# - Lemmatization can be implemented in python by using Wordnet Lemmatizer, Spacy Lemmatizer, TextBlob, Stanford CoreNLP

# %%
# Importing Lemmatizer library from nltk
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer() 
 
print("rocks :", lemmatizer.lemmatize("rocks")) 
print("corpora :", lemmatizer.lemmatize("corpora"))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# rocks : rock
# corpora : corpus

# %% [markdown]
# Stop Words: “Stop words” are the most common words in a language like “the”, “a”, “at”, “for”, “above”, “on”, “is”, “all”. These words do not provide any meaning and are usually removed from texts. We can remove these stop words using nltk library

# %%
# importing stopwors from nltk library

import nltk
nltk.download('stopwords')
from nltk import word_tokenize
from nltk.corpus import stopwords
a = set(stopwords.words('english'))

# Input the data (Open a text file for reading)
text = open('JD.txt', 'r')

# Store content in a variable
text = text.read()

text1 = word_tokenize(text.lower())
print(text1)
stopwords = [x for x in text1 if x not in a]
print(stopwords)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['data', 'analyst', '-', 'geotab', 'hiring', 'manager', '-', 'james', 'brown', 'location', '-', 'oakville', 'who', 'we', 'are', ':', 'geotab', 'is', 'a', 'global', 'leader', 'in', 'iot', 'and', 'connected', 'transportation', 'and', 'certified', '“', 'great', 'place', 'to', 'work.', '”', 'we', 'are', 'a', 'company', 'of', 'diverse', 'and', 'talented', 'individuals', 'who', 'work', 'together', 'to', 'help', 'businesses', 'grow', 'and', 'succeed', ',', 'and', 'increase', 'the', 'safety', 'and', 'sustainability', 'of', 'our', 'communities', '.', 'geotab', 'is', 'advancing', 'security', ',', 'connecting', 'commercial', 'vehicles', 'to', 'the', 'internet', 'and', 'providing', 'web-based', 'analytics', 'to', 'help', 'customers', 'better', 'manage', 'their', 'fleets', '.', 'geotab', '’', 's', 'open', 'platform', 'and', 'marketplace', ',', 'offering', 'hundreds', 'of', 'third-party', 'solution', 'options', ',', 'allows', 'both', 'small', 'and', 'large', 'businesses', 'to', 'automate', 'operations', 'by', 'integrating', 'vehicle', 'data', 'with', 'their', 'other', 'data', 'assets', '.', 'processing', 'billions', 'of', 'data', 'points', 'a', 'day', ',', 'geotab', 'leverages', 'data', 'analytics', 'and', 'machine', 'learning', 'to', 'improve', 'productivity', ',', 'optimize', 'fleets', 'through', 'the', 'reduction', 'of', 'fuel', 'consumption', ',', 'enhance', 'driver', 'safety', 'and', 'achieve', 'strong', 'compliance', 'to', 'regulatory', 'changes', '.', 'our', 'team', 'is', 'growing', 'and', 'we', '’', 're', 'looking', 'for', 'people', 'who', 'follow', 'their', 'passion', ',', 'think', 'differently', 'and', 'want', 'to', 'make', 'an', 'impact', '.', 'join', 'us', 'for', 'a', 'fulfilling', 'career', 'with', 'opportunities', 'to', 'innovate', ',', 'great', 'benefits', ',', 'and', 'our', 'fun', 'and', 'inclusive', 'work', 'culture', '.', 'reach', 'your', 'full', 'potential', 'with', 'geotab', '.', 'to', 'see', 'what', 'it', '’', 's', 'like', 'to', 'be', 'a', 'geotabber', ',',
'enhance', 'driver', 'safety', 'achieve', 'strong', 'compliance', 'regulatory', 'changes', '.', 'team', 'growing', '’', 'looking', 'people', 'follow', 'passion', ',', 'think', 'differently', 'want', 'make', 'impact', '.', 'join', 'us', 'fulfilling', 'career', 'opportunities', 'innovate', ',', 'great', 'benefits', ',', 'fun', 'inclusive', 'work', 'culture', '.', 'reach', 'full', 'potential', 'geotab', '.', 'see', '’', 'like', 'geotabber', ',', 'follow', 'us', '@', 'insidegeotab', 'instagram', ',', 'twitter', 'facebook', '.', 'looking', ':', 'looking', 'data', 'analysts', 'help', 'us', 'discover', 'value', 'rich', 'large', 'datasets', '.', 'ideal', 'team', 'member', 'mathematical', 'statistical', 'expertise', '’', 'expect', ',', 'natural', 'curiosity', 'creative', 'mind', '’', 'easy', 'find', '.', 'mine', ',', 'interpret', 'clean', 'data', ',', 'rely', 'ask', 'questions', ',', 'connect', 'dots', 'uncover', 'opportunities', 'lie', 'hidden', 'within', ',', 'ultimate', 'goal', 'realizing', 'data', '’', 'full', 'potential', '.', 'details', 'position', ':', 'data', 'analyst', 'join', 'rma', 'team', 'operations', 'analyze', 'well-defined', 'sets', 'data', 'using', 'variety', 'different', 'tools', 'answer', 'tangible', 'business', 'needs', 'find', 'meaningful', 'insights', '.', 'position', 'understand', 'internal', 'departments', 'directly', 'benefit', 'analysis', 'develop', 'products', 'results', '.', 'position', 'works', 'closely', 'data', 'professionals', 'within', 'data', '&', 'analytics', 'teams', '.', 'duties', 'tasks/essential', 'functions', ':', 'examine', 'large', 'data', 'sets', 'identify', 'trends', ',', 'develop', 'charts', ',', 'creative', 'visual', 'presentations', 'help', 'businesses', 'make', 'strategic', 'decisions', '.', 'maintain', 'data', 'systems', 'databases', '.', 'utilize', 'statistical', 'tools', 'interpret', 'data', 'sets', 'prepare', 'reports', 'effectively', 'communicate', 'trends', ',', 'patterns', ',', 'predictions', 'based', 'relevant', 'findings', '.', 'write', 'sql', 'queries', 'find', 'answers', 'complex', 'business', 'questions', '.', 'identify', 'data', 'quality', 'issues', 'partialities', 'data', 'acquisition', '.', 'coordinate', 'engineering', 'team', 'gather', 'incremental', 'new', 'data', '.', 'process', ',', 'cleanse', 'verify', 'integrity', 'data', 'used', 'analysis', '.', 'use', 'data', 'mining', ',', 'model', 'building', ',', 'analytical', 'techniques', 'support', 'internal', 'initiatives', '.', 'assist', 'internal', 'technical', 'departments', 'providing', 'meaningful', 'insight', 'using', 'datasets', '.', 'work', 'data', 'scientists', 'leverage', 'machine', 'learning', 'models', 'developed', 'geotab', "'s", 'big', 'data', 'environment', '.', 'experience/skills', 'required', ':', '0-5', 'years', 'experience', 'data', 'analyst', 'similar', 'role', '.', '3-5', 'years', 'experience', 'sql', '.', '3-5', 'years', 'experience', 'data', 'science', 'tools', '(', ...

# %% [markdown]
# Part of speech tagging (POS)
#
# - Part-of-speech tagging is used to assign parts of speech to each word of a given text (such as nouns, verbs, pronouns, adverbs, conjunction, adjectives, interjection) based on its definition and its context. There are many tools available for POS taggers and some of the widely used taggers are NLTK, Spacy, TextBlob, Standford CoreNLP, etc.

# %%
import nltk
nltk.download('averaged_perceptron_tagger')

# Input the data (Open a text file for reading)
text = open('JD.txt', 'r')

# Store content in a variable
text = text.read()

# Tokenize the text

tex = word_tokenize(text)
for token in tex:
  print(nltk.pos_tag([token]))
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('Data', 'NNS')]
# [('Analyst', 'NN')]
# [('-', ':')]
# [('Geotab', 'NN')]
# [('Hiring', 'VBG')]
# [('Manager', 'NN')]
# [('-', ':')]
# [('James', 'NNP')]
# [('Brown', 'NNP')]
# [('Location', 'NN')]
# [('-', ':')]
# [('Oakville', 'NNP')]
# [('Who', 'WP')]
# [('we', 'PRP')]
# [('are', 'VBP')]
# [(':', ':')]
# [('Geotab', 'NN')]
# [('is', 'VBZ')]
# [('a', 'DT')]
# [('global', 'JJ')]
# [('leader', 'NN')]
# [('in', 'IN')]
# [('IoT', 'NN')]
# [('and', 'CC')]
# [('connected', 'VBN')]
# [('transportation', 'NN')]
# [('and', 'CC')]
# [('certified', 'VBN')]
# [('“', 'NN')]
# [('Great', 'NN')]
# [('Place', 'NN')]
# [('to', 'TO')]
# [('Work.', 'NN')]
# [('”', 'NN')]
# [('We', 'PRP')]
# [('are', 'VBP')]
# [('a', 'DT')]
# [('company', 'NN')]
# [('of', 'IN')]
# [('diverse', 'NN')]
# [('and', 'CC')]
# [('talented', 'VBN')]
# [('individuals', 'NNS')]
# [('who', 'WP')]
# [('work', 'NN')]
# [('together', 'RB')]
# [('to', 'TO')]
# [('help', 'NN')]
# [('businesses', 'NNS')]
# [('grow', 'NN')]
# [('and', 'CC')]
# [('succeed', 'VB')]
# [(',', ',')]
# [('and', 'CC')]
# [('increase', 'NN')]
# [('the', 'DT')]
# [('safety', 'NN')]
# [('and', 'CC')]
# [('sustainability', 'NN')]
# [('of', 'IN')]
# [('our', 'PRP$')]
# [('communities', 'NNS')]
# [('.', '.')]
# [('Geotab', 'NN')]
# [('is', 'VBZ')]
# [('advancing', 'VBG')]
# [('security', 'NN')]
# [(',', ',')]
# [('connecting', 'VBG')]
# [('commercial', 'JJ')]
# [('vehicles', 'NNS')]
# [('to', 'TO')]
# [('the', 'DT')]
# [('internet', 'NN')]
# [('and', 'CC')]
# [('providing', 'VBG')]
# [('web-based', 'JJ')]
# [('analytics', 'NNS')]
# [('to', 'TO')]
# [('help', 'NN')]
# [('customers', 'NNS')]
# [('better', 'RBR')]
# [('manage', 'NN')]
# [('their', 'PRP$')]
# [('fleets', 'NNS')]
# [('.', '.')]
# [('Geotab', 'NN')]
# [('’', 'NN')]
# [('s', 'NN')]
# [('open', 'JJ')]
# [('platform', 'NN')]
# [('and', 'CC')]
# [('Marketplace', 'NN')]
# [(',', ',')]
# [('offering', 'NN')]
# [('hundreds', 'NNS')]
# [('of', 'IN')]
# [('third-party', 'NN')]
# [('solution', 'NN')]
# [('options', 'NNS')]
# [(',', ',')]
# [('allows', 'NNS')]
# [('both', 'DT')]
# [('small', 'JJ')]
# [('and', 'CC')]
# [('large', 'JJ')]
# [('businesses', 'NNS')]
# [('to', 'TO')]
# [('automate', 'NN')]
# [('operations', 'NNS')]
# [('by', 'IN')]
# [('integrating', 'VBG')]
]
# [('Data', 'NNS')]
# [('Analyst', 'NN')]
# [('will', 'MD')]
# [('join', 'NN')]
# [('RMA', 'NN')]
# [('team', 'NN')]
# [('under', 'IN')]
# [('Operations', 'NNS')]
# [('and', 'CC')]
# [('will', 'MD')]
# [('analyze', 'NN')]
# [('well-defined', 'JJ')]
# [('sets', 'NNS')]
# [('of', 'IN')]
# [('data', 'NNS')]
# [('using', 'VBG')]
# [('a', 'DT')]
# [('variety', 'NN')]
# [('of', 'IN')]
# [('different', 'JJ')]
# [('tools', 'NNS')]
# [('to', 'TO')]
# [('answer', 'NN')]
# [('tangible', 'JJ')]
# [('business', 'NN')]
# [('needs', 'NNS')]
# [('and', 'CC')]
# [('find', 'VB')]
# [('meaningful', 'NN')]
# [('insights', 'NNS')]
# [('.', '.')]
# [('The', 'DT')]
# [('position', 'NN')]
# [('will', 'MD')]
# [('understand', 'NN')]
# [('how', 'WRB')]
# [('internal', 'JJ')]
# [('departments', 'NNS')]
# [('can', 'MD')]
# [('directly', 'RB')]
# [('benefit', 'NN')]
# [('from', 'IN')]
# [('the', 'DT')]
# [('analysis', 'NN')]
# [('and', 'CC')]
# [('develop', 'VB')]
# [('products', 'NNS')]
# [('from', 'IN')]
# [('these', 'DT')]
# [('results', 'NNS')]
# [('.', '.')]
# [('The', 'DT')]
# [('position', 'NN')]
# [('works', 'NNS')]
# [('closely', 'RB')]
# [('with', 'IN')]
# [('Data', 'NNS')]
# [('professionals', 'NNS')]
# [('within', 'IN')]
# [('the', 'DT')]
# [('Data', 'NNS')]
# [('&', 'CC')]
# [('Analytics', 'NNS')]
# [('Teams', 'NNS')]
# [('.', '.')]
# [('Duties', 'NNS')]
# [('and', 'CC')]
# [('Tasks/Essential', 'JJ')]
# [('Functions', 'NNS')]
# [(':', ':')]
# [('Examine', 'NN')]
# [('large', 'JJ')]
# [('data', 'NNS')]
# [('sets', 'NNS')]
# [('to', 'TO')]
# [('identify', 'VB')]
# [('trends', 'NNS')]
# [(',', ',')]
# [('develop', 'VB')]
# [('charts', 'NNS')]
# [(',', ',')]
# [('and', 'CC')]
# [('creative', 'JJ')]
# [('visual', 'JJ')]
# [('presentations', 'NNS')]
# [('to', 'TO')]
# [('help', 'NN')]
# [('businesses', 'NNS')]
# [('make', 'VB')]
# [('more', 'RBR')]
# [('strategic', 'JJ')]
# [('decisions', 'NNS')]
# [('.', '.')]
# [('Maintain', 'NN')]
# [('data', 'NNS')]
# [('systems', 'NNS')]
# [('and', 'CC')]
# [('databases', 'NNS')]
# [('.', '.')]
# [('Utilize', 'VB')]
# [('statistical', 'JJ')]
# [('tools', 'NNS')]
# [('to', 'TO')]
# [('interpret', 'NN')]
# [('data', 'NNS')]
# [('sets', 'NNS')]
# [('and', 'CC')]
# [('prepare', 'NN')]
# [('reports', 'NNS')]
# [('that', 'IN')]
# [('effectively', 'RB')]
# [('communicate', 'NN')]
# [('trends', 'NNS')]
# [(',', ',')]
# [('patterns', 'NNS')]
# [(',', ',')]
# [('and', 'CC')]
# [('predictions', 'NNS')]
# [('based', 'VBN')]
# [('on', 'IN')]
# [('relevant', 'NN')]
# [('findings', 'NNS')]
# [('.', '.')]
# [('Write', 'VB')]
# [('SQL', 'NN')]
# [('queries', 'NNS')]
# [('to', 'TO')]
# [('find', 'VB')]
# [('answers', 'NNS')]
# [('to', 'TO')]
# [('complex', 'JJ')]
# [('business', 'NN')]
# [('questions', 'NNS')]
# [('.', '.')]
# [('Identify', 'VB')]
# [('any', 'DT')]
# [('data', 'NNS')]
# [('quality', 'NN')]
# [('issues', 'NNS')]
# [('and', 'CC')]
# [('partialities', 'NNS')]
# [('in', 'IN')]
# [('data', 'NNS')]
# [('acquisition', 'NN')]
# [('.', '.')]
# [('Coordinate', 'NN')]
# [('with', 'IN')]
# [('the', 'DT')]
# [('engineering', 'NN')]
# [('team', 'NN')]
# [('to', 'TO')]
# [('gather', 'NN')]
# [('incremental', 'NN')]
# [('new', 'JJ')]
# [('data', 'NNS')]
# [('.', '.')]
# [('Process', 'NN')]
# [(',', ',')]
# [('cleanse', 'NN')]
# [('and', 'CC')]
# [('verify', 'NN')]
# [('the', 'DT')]
# [('integrity', 'NN')]
# [('of', 'IN')]
# [('data', 'NNS')]
# [('used', 'VBN')]
# [('for', 'IN')]
# [('analysis', 'NN')]
# [('.', '.')]
# [('Use', 'NN')]
# [('data', 'NNS')]
# [('mining', 'NN')]
# [(',', ',')]
# [('model', 'NN')]
# [('building', 'NN')]
# [(',', ',')]
# [('and', 'CC')]
# [('other', 'JJ')]
# [('analytical', 'JJ')]
# [('techniques', 'NNS')]
# [('to', 'TO')]
# [('support', 'NN')]
# [('internal', 'JJ')]
# [('initiatives', 'NNS')]
# [('.', '.')]
# [('Assist', 'NN')]
# [('the', 'DT')]
# [('internal', 'JJ')]
# [('technical', 'JJ')]
# [('departments', 'NNS')]
# [('by', 'IN')]
# [('providing', 'VBG')]
# [('meaningful', 'NN')]
# [('insight', 'NN')]
# [('using', 'VBG')]
# [('datasets', 'NNS')]
# [('.', '.')]
# [('Work', 'NN')]
# [('with', 'IN')]
# [('data', 'NNS')]
# [('scientists', 'NNS')]
# [('and', 'CC')]
# [('leverage', 'NN')]
# [('machine', 'NN')]
# [('learning', 'VBG')]
# [('models', 'NNS')]
# [('that', 'IN')]
# [('have', 'VB')]
# [('been', 'VBN')]
# [('developed', 'NN')]
# [('against', 'IN')]
# [('Geotab', 'NN')]
# [("'s", 'POS')]
# [('big', 'JJ')]
# [('data', 'NNS')]
# [('environment', 'NN')]
# [('.', '.')]
# [('Experience/Skills', 'NNS')]
# [('Required', 'VBN')]
# [(':', ':')]
# [('0-5', 'NN')]
# [('years', 'NNS')]
# [('experience', 'NN')]
# [('as', 'IN')]
# [('a', 'DT')]
# [('Data', 'NNS')]
# [('Analyst', 'NN')]
# [('or', 'CC')]
# [('a', 'DT')]
# [('similar', 'JJ')]
# [('role', 'NN')]
# [('.', '.')]
# [('3-5', 'JJ')]
# [('years', 'NNS')]
# [('experience', 'NN')]
# [('with', 'IN')]
# [('SQL', 'NN')]
# [('.', '.')]
# [('3-5', 'JJ')]
# [('years', 'NNS')]
# [('experience', 'NN')]
# [('with', 'IN')]
# [('data', 'NNS')]
# [('science', 'NN')]
# [('tools', 'NNS')]
# [('(', '(')]
# [('e.g', 'NN')]
# [('Python', 'NN')]
# [(',', ',')]
# [('Pandas', 'NNS')]
# [(',', ',')]
# [('NumPy', 'NN')]
# [(')', ')')]
# [('.', '.')]
# [('Tokyo', 'NNP')]
# [(',', ',')]
# [('London', 'NNP')]
# [(',', ',')]
# [('Sydney', 'NN')]
# [('and', 'CC')]
# [('Bangalore', 'IN')]
# [(',', ',')]
# [('we', 'PRP')]
# [('truly', 'RB')]
# [('believe', 'VB')]
# [('in', 'IN')]
# [('finding', 'VBG')]
# [('the', 'DT')]
# [('best', 'JJS')]
# [('talent', 'NN')]
# [('everywhere', 'RB')]
# [('.', '.')]
# [('We', 'PRP')]
# [('also', 'RB')]
# [('embrace', 'NN')]
# [('the', 'DT')]
# [('Work', 'NN')]
# [('from', 'IN')]
# [('Home', 'NN')]
# [('movement', 'NN')]
# [('and', 'CC')]
# [('are', 'VBP')]
# [('just', 'RB')]
# [('as', 'IN')]
# [('happy', 'JJ')]
# [('hiring', 'VBG')]
# [('great', 'JJ')]
# [('talent', 'NN')]
# [('from', 'IN')]
# [('anywhere', 'RB')]
# [('if', 'IN')]
# [('they', 'PRP')]
# [('choose', 'NN')]
# [('to', 'TO')]
# [('work', 'NN')]
# [('from', 'IN')]
# [('home', 'NN')]
# [('rather', 'RB')]
# [('than', 'IN')]
# [('in', 'IN')]
# [('an', 'DT')]
# [('office', 'NN')]
# [('.', '.')]
# [('With', 'IN')]
# [('over', 'IN')]
# [('$', '$')]
# [('220', 'CD')]
# [('million', 'CD')]
# [('in', 'IN')]
# [('funding', 'NN')]
# [('from', 'IN')]
# [('OMERS', 'NNS')]
# [('Growth', 'NN')]
# [('Equity', 'NN')]
# [(',', ',')]
# [('ICONIQ', 'NN')]
# [('Capital', 'NN')]
# [(',', ',')]
# [('GV', 'NN')]
# [(',', ',')]
# [('Andreessen', 'NNP')]
# [('Horowitz', 'NN')]
# [(',', ',')]
# [('Felicis', 'NN')]
# [('Ventures', 'NNS')]
# [(',', ',')]
# [('Work-Bench', 'JJ')]
# [(',', ',')]
# [('Scale', 'NN')]
# [('Ventures', 'NNS')]
# [('and', 'CC')]
# [('other', 'JJ')]
# [('top', 'NN')]
# [('VCs', 'NN')]
# [(',', ',')]
# [('Dialpad', 'NN')]
# [('attracts', 'NNS')]
# [('top', 'NN')]
# [('engineers', 'NNS')]
# [('from', 'IN')]
# [('companies', 'NNS')]
# [('like', 'IN')]
# [('Microsoft', 'NNP')]
# [('and', 'CC')]
# [('Google', 'NN')]
# [(',', ',')]
# [('and', 'CC')]
# [('every', 'DT')]
# [('member', 'NN')]
# [('of', 'IN')]
# [('our', 'PRP$')]
# [('team', 'NN')]
# [('plays', 'NNS')]
# [('an', 'DT')]
# [('essential', 'JJ')]
# [('role', 'NN')]
# [('in', 'IN')]
# [('creating', 'VBG')]
# [('dynamic', 'JJ')]
# [('products', 'NNS')]
# [('that', 'IN')]
# [('enable', 'JJ')]
# [('workers', 'NNS')]
# [('to', 'TO')]
# [('be', 'VB')]
# [('productive', 'JJ')]
# [('from', 'IN')]
# [('anywhere', 'RB')]
# [('!', '.')]
# [('About', 'IN')]
# [('the', 'DT')]
# [('Role', 'NN')]
# [(':', ':')]
# [('The', 'DT')]
# [('machine', 'NN')]
# [('learning', 'VBG')]
# [('team', 'NN')]
# [('is', 'VBZ')]
# [('responsible', 'JJ')]
# [('for', 'IN')]
# [('building', 'NN')]
# [('all', 'DT')]
# [('the', 'DT')]
# [('models', 'NNS')]
# [('used', 'VBN')]
# [('to', 'TO')]
# [('deliver', 'NN')]
# [('our', 'PRP$')]
# [('Voice', 'NN')]
# [('Intelligence', 'NN')]
# [('AI', 'NN')]
# [('technology', 'NN')]
# [('.', '.')]
# [('We', 'PRP')]
# [('are', 'VBP')]
# [('looking', 'VBG')]
# [('for', 'IN')]
# [('a', 'DT')]
# [('Data', 'NNS')]
# [('Analyst', 'NN')]
# [('who', 'WP')]
# [('will', 'MD')]
# [('support', 'NN')]
# [('our', 'PRP$')]
# [('Data', 'NNS')]
# [('Science', 'NN')]
# [(',', ',')]
# [('Speech', 'NN')]
# [('Recognition', 'NN')]
# [(',', ',')]
# [('and', 'CC')]
# [('Data', 'NNS')]
# [('Engineering', 'VBG')]
# [('teams', 'NNS')]
# [('to', 'TO')]
# [('help', 'NN')]
# [('deliver', 'NN')]
# [('valuable', 'JJ')]
# [('insights', 'NNS')]
# [('to', 'TO')]
# [('customers', 'NNS')]
# [('.', '.')]
# [('The', 'DT')]
# [('ideal', 'NN')]
# [('person', 'NN')]
# [('has', 'VBZ')]
# [('excellent', 'NN')]
# [('critical', 'JJ')]
# [('thinking', 'VBG')]
# [('skills', 'NNS')]
# [(',', ',')]
# [('attention', 'NN')]
# [('to', 'TO')]
# [('detail', 'NN')]
# [(',', ',')]
# [('can', 'MD')]
# [('handle', 'NN')]
# [('large', 'JJ')]
# [('data', 'NNS')]
# [('sets', 'NNS')]
# [(',', ',')]
# [('and', 'CC')]
# [('can', 'MD')]
# [('work', 'NN')]
# [('in', 'IN')]
# [('the', 'DT')]
# [('gap', 'NN')]
# [('between', 'IN')]
# [('business', 'NN')]
# [('stakeholders', 'NNS')]
# [('and', 'CC')]
# [('speech/language', 'NN')]
# [('scientists', 'NNS')]
# [('.', '.')]
# [('The', 'DT')]
# [('data', 'NNS')]
# [('analyst', 'NN')]
# [('will', 'MD')]
# [('work', 'NN')]
# [('closely', 'RB')]
# [('with', 'IN')]
# [('the', 'DT')]
# [('Speech', 'NN')]
# [('and', 'CC')]
# [('Natural', 'JJ')]
# [('Language', 'NN')]
# [('Processing', 'VBG')]
# [('teams', 'NNS')]
# [('to', 'TO')]
# [('do', 'VB')]
# [('insightful', 'NN')]
# [('analysis', 'NN')]
# [('across', 'IN')]
# [('huge', 'JJ')]
# [('collections', 'NNS')]
# [('of', 'IN')]
# [('conversations', 'NNS')]
# [('to', 'TO')]
# [('help', 'NN')]
# [('identify', 'VB')]
# [('trends', 'NNS')]
# [('in', 'IN')]
# [('our', 'PRP$')]
# [('transcriptions', 'NNS')]
# [(',', ',')]
# [('how', 'WRB')]
# [('we', 'PRP')]
# [('can', 'MD')]
# [('reduce', 'VB')]
# [('the', 'DT')]
# [('bias', 'NN')]
# [('in', 'IN')]
# [('our', 'PRP$')]
# [('ASR', 'NN')]
# [('systems', 'NNS')]
# [(',', ',')]
# [('and', 'CC')]
# [
]
# [('Data', 'NNS')]
# [('Analyst', 'NN')]
# [('-', ':')]
# [('Wellington-Altus', 'JJ')]
# [('Private', 'JJ')]
# [('Wealth', 'NN')]
# [('-', ':')]
# [('Winnipeg', 'NN')]
# [(',', ',')]
# [('MB', 'NN')]
# [('Wellington-Altus', 'JJ')]
# [('is', 'VBZ')]
# [('currently', 'RB')]
# [('recruiting', 'NN')]
# [('for', 'IN')]
# [('a', 'DT')]
# [('Data', 'NNS')]
# [('Analyst', 'NN')]
# [('position', 'NN')]
# [('.', '.')]
# [('The', 'DT')]
# [('Data', 'NNS')]
# [('Analyst', 'NN')]
# [('will', 'MD')]
# [('work', 'NN')]
# [('with', 'IN')]
# [('the', 'DT')]
# [('Wellington', 'NNP')]
# [('Labs', 'NNS')]
# [('team', 'NN')]
# [('to', 'TO')]
# [('provide', 'NN')]
# [('data', 'NNS')]
# [('solutions', 'NNS')]
# [('to', 'TO')]
# [('power', 'NN')]
# [('business', 'NN')]
# [('applications', 'NNS')]
# [('.', '.')]
# [('In', 'IN')]
# [('this', 'DT')]
# [('role', 'NN')]
# [(',', ',')]
# [('you', 'PRP')]
# [('will', 'MD')]
# [('work', 'NN')]
# [('on', 'IN')]
# [('projects', 'NNS')]
# [('in', 'IN')]
# [('a', 'DT')]
# [('growing', 'VBG')]
# [('organization', 'NN')]
# [('with', 'IN')]
# [('opportunities', 'NNS')]
# [('to', 'TO')]
# [('address', 'NN')]
# [('problems', 'NNS')]
# [('needing', 'VBG')]
# [('creative', 'JJ')]
# [('solutions', 'NNS')]
# [('and', 'CC')]
# [('models', 'NNS')]
# [('.', '.')]
# [('You', 'PRP')]
# [('will', 'MD')]
# [('be', 'VB')]
# [('working', 'VBG')]
# [('on', 'IN')]
# [('bringing', 'VBG')]
# [('together', 'RB')]
# [('different', 'JJ')]
# [('data', 'NNS')]
# [('sets', 'NNS')]
# [('from', 'IN')]
# [('across', 'IN')]
# [('locations', 'NNS')]
# [('and', 'CC')]
# [('modeling', 'VBG')]
# [('data', 'NNS')]
# [('to', 'TO')]
# [('unlock', 'NN')]
# [('actionable', 'JJ')]
# [('insights', 'NNS')]
# [('that', 'IN')]
# [('help', 'NN')]
# [('stakeholders', 'NNS')]
# [('formulate', 'NN')]
# [('and', 'CC')]
# [('answer', 'NN')]
# [('business', 'NN')]
# [('questions', 'NNS')]
# [('.', '.')]
# [('You', 'PRP')]
# [('will', 'MD')]
# [('collaborate', 'NN')]
# [('closely', 'RB')]
# [('with', 'IN')]
# [('stakeholders', 'NNS')]
# [('from', 'IN')]
# [('technical', 'JJ')]
# [('solutions', 'NNS')]
# [('engineering', 'NN')]
# [(',', ',')]
# [('product', 'NN')]
# [('programs', 'NNS')]
# [(',', ',')]
# [('vendor', 'NN')]
# [('operations', 'NNS')]
# [(',', ',')]
# [('support', 'NN')]
# [('operations', 'NNS')]
# [(',', ',')]
# [('and', 'CC')]
# [('support', 'NN')]
# [('experience', 'NN')]
# [('teams', 'NNS')]
# [('.', '.')]
# [('As', 'IN')]
# [('a', 'DT')]
# [('Data', 'NNS')]
# [('Analyst', 'NN')]
# [(',', ',')]
# [('you', 'PRP')]
# [('will', 'MD')]
# [(':', ':')]
# [('Provide', 'VB')]
# [('decision-making', 'NN')]
# [('support', 'NN')]
# [('for', 'IN')]
# [('key', 'NN')]
# [('projects', 'NNS')]
# [(',', ',')]
# [('and', 'CC')]
# [('research', 'NN')]
# [('new', 'JJ')]
# [('ways', 'NNS')]
# [('of', 'IN')]
# [('modeling', 'VBG')]
# [('data', 'NNS')]
# [('to', 'TO')]
# [('unlock', 'NN')]
# [('actionable', 'JJ')]
# [('insights', 'NNS')]
# [('or', 'CC')]
# [('improve', 'VB')]
# [('processes', 'NNS')]
# [('.', '.')]
# [('Write', 'VB')]
# [('and', 'CC')]
# [('review', 'NN')]
# [('technical', 'JJ')]
# [('documents', 'NNS')]
# [(',', ',')]
# [('including', 'VBG')]
# [('requirements', 'NNS')]
# [('and', 'CC')]
# [('design', 'NN')]
# [('documents', 'NNS')]
# [('for', 'IN')]
# [('existing', 'VBG')]
# [('and', 'CC')]
# [('future', 'NN')]
# [('data', 'NNS')]
# [('systems', 'NNS')]
# [(',', ',')]
# [('as', 'IN')]
# [('well', 'RB')]
# [('as', 'IN')]
# [('data', 'NNS')]
# [('standards', 'NNS')]
# [('and', 'CC')]
# [('policies', 'NNS')]
# [('.', '.')]
# [('Partner', 'NN')]
# [('with', 'IN')]
# [('non-technical', 'JJ')]
# [('stakeholders', 'NNS')]
# [('to', 'TO')]
# [('understand', 'NN')]
# [('their', 'PRP$')]
# [('needs', 'NNS')]
# [(',', ',')]
# [('help', 'NN')]
# [('frame', 'NN')]
# [('the', 'DT')]
# [('problem', 'NN')]
# [('by', 'IN')]
# [('asking', 'VBG')]
# [('the', 'DT')]
# [('right', 'NN')]
# [('questions', 'NNS')]
# [(',', ',')]
# [('and', 'CC')]
# [('document', 'NN')]
# [('and', 'CC')]
# [('prioritize', 'NN')]
# [('requirements', 'NNS')]
# [('.', '.')]
# [('Communicate', 'NN')]
# [('results', 'NNS')]
# [('of', 'IN')]
# [('technical', 'JJ')]
# [('work', 'NN')]
# [('.', '.')]
# [('Design', 'NN')]
# [(',', ',')]
# [('write', 'NN')]
# [(',', ',')]
# [('and', 'CC')]
# [('support', 'NN')]
# [('extract', 'NN')]
# [(',', ',')]
# [('transform', 'NN')]
# [(',', ',')]
# [('and', 'CC')]
# [('load', 'NN')]
# [('(', '(')]
# [('ETL', 'NN')]
# [(')', ')')]
# [('processes', 'NNS')]
# [('to', 'TO')]
# [('automate', 'NN')]
# [('data', 'NNS')]
# [('collection', 'NN')]
# [('and', 'CC')]
# [('manage', 'NN')]
# [('pipelines', 'NNS')]
# [('.', '.')]
# [('Your', 'PRP$')]
# [('education', 'NN')]
# [('and', 'CC')]
# [('qualifications', 'NNS')]
# [('include', 'NN')]
# [(':', ':')]
# [('BS', 'NN')]
# [('degree', 'NN')]
# [('in', 'IN')]
# [('Information', 'NN')]
# [('Management', 'NN')]
# [(',', ',')]
# [('Computer', 'NNP')]
# [('Science', 'NN')]
# [(',', ',')]
# [('Statistics', 'NNS')]
# [('or', 'CC')]
# [('similar', 'JJ')]
# [('.', '.')]
# [('Experience', 'NN')]
# [('in', 'IN')]
# [('AWS', 'NN')]
# [('administration', 'NN')]
# [('.', '.')]
# [('3', 'CD')]
# [('years', 'NNS')]
# [('of', 'IN')]
# [('experience', 'NN')]
# [('in', 'IN')]
# [('an', 'DT')]
# [('analyst', 'NN')]
# [('or', 'CC')]
# [('Data', 'NNS')]
# [('Science', 'NN')]
# [('role', 'NN')]
# [('.', '.')]
# [('Experience', 'NN')]
# [('using', 'VBG')]
# [('SQL', 'NN')]
# [('to', 'TO')]
# [('work', 'NN')]
# [('with', 'IN')]
# [('multiple', 'NN')]
# [('datasets', 'NNS')]
# [('.', '.')]
# [('Experience', 'NN')]
# [('designing', 'VBG')]
# [('data', 'NNS')]
# [('models', 'NNS')]
# [('and', 'CC')]
# [('building', 'NN')]
# [('data', 'NNS')]
# [('structures', 'NNS')]
# [('.', '.')]
# [('Experience', 'NN')]
# [('in', 'IN')]
# [('a', 'DT')]
# [('language', 'NN')]
# [('for', 'IN')]
# [('statistical', 'JJ')]
# [('computing', 'VBG')]
# [('(', '(')]
# [('R', 'NN')]
# [(',', ',')]
# [('Python/pandas', 'NNS')]
# [(',', ',')]
# [('Stata', 'NN')]
# [(',', ',')]
# [('etc.', 'NN')]
# [(')', ')')]
# [('.', '.')]
# [('Conditions', 'NNS')]
# [('of', 'IN')]
# [('Employment', 'NN')]
# [(':', ':')]
# [('Must', 'NN')]
# [('be', 'VB')]
# [('legally', 'RB')]
# [('eligible', 'JJ')]
# [('to', 'TO')]
# [('work', 'NN')]
# [('in', 'IN')]
# [('Canada', 'NNP')]
# [('A', 'DT')]
# [('background', 'NN')]
# [('check', 'NN')]
# [(',', ',')]
# [('satisfactory', 'NN')]
# [('to', 'TO')]
# [('the', 'DT')]
# [('employer', 'NN')]
# [(',', ',')]
# [('may', 'MD')]
# [('be', 'VB')]
# [('required', 'VBN')]
# [('of', 'IN')]
# [('the', 'DT')]
# [('successful', 'JJ')]
# [('applicant', 'NN')]
# [('prior', 'RB')]
# [('to', 'TO')]
# [('commencing', 'VBG')]
# [('employment', 'NN')]
# [('Wellington-Altus', 'JJ')]
# [('Private', 'JJ')]
# [('Wealth', 'NN')]
# [('is', 'VBZ')]
# [('strongly', 'RB')]
# [('committed', 'VBN')]
# [('to', 'TO')]
# [('equity', 'NN')]
# [('and', 'CC')]
# [('diversity', 'NN')]
# [('within', 'IN')]
# [('its', 'PRP$')]
# [('community', 'NN')]
# [('and', 'CC')]
# [('welcomes', 'NNS')]
# [('applications', 'NNS')]
# [('from', 'IN')]
# [('women', 'NNS')]
# [(',', ',')]
# [('racialized', 'VBN')]
# [('persons', 'NNS')]
# [(',', ',')]
# [('Indigenous', 'JJ')]
# [('peoples', 'NNS')]
# [(',', ',')]
# [('persons', 'NNS')]
# [('with', 'IN')]
# [('disabilities', 'NNS')]
# [(',', ',')]
# [('and', 'CC')]
# [('persons', 'NNS')]
# [('of', 'IN')]
# [('all', 'DT')]
# [('sexual', 'JJ')]
# [('orientations', 'NNS')]
# [('and', 'CC')]
# [('genders', 'NNS')]
# [('.', '.')]
# [('All', 'DT')]
# [('qualified', 'VBN')]
# [('individuals', 'NNS')]
# [('who', 'WP')]
# [('would', 'MD')]
# [('contribute', 'NN')]
# [('to', 'TO')]
# [('the', 'DT')]
# [('further', 'RB')]
# [('diversification', 'NN')]
# [('of', 'IN')]
# [('our', 'PRP$')]
# [('organization', 'NN')]
# [('are', 'VBP')]
# [('encouraged', 'VBN')]
# [('to', 'TO')]
# [('apply', 'VB')]
# [('.', '.')]
# [('If', 'IN')]
# [('you', 'PRP')]
# [('require', 'NN')]
# [('accommodation', 'NN')]
# [('for', 'IN')]
# [('the', 'DT')]
# [('recruitment', 'NN')]
# [('process', 'NN')]
# [(',', ',')]
# [('please', 'NN')]
# [('let', 'VB')]
# [('us', 'PRP')]
# [('know', 'VB')]
# [('at', 'IN')]
# [('the', 'DT')]
# [('point', 'NN')]
# [('of', 'IN')]
# [('application', 'NN')]
# [('.', '.')]

# %% [markdown]
# Named entity recognition: It is the process of detecting the named entities such as the person name, the location name, the company name, the quantities and the monetary value.

# %%
import nltk
nltk.download('maxent_ne_chunker')

# Input the data (Open a text file for reading)
text = open('JD.txt', 'r')

# Store content in a variable
text = text.read()

#importing chunk library from nltk

import nltk
nltk.download('words')
from nltk import ne_chunk

# tokenize and POS Tagging before doing chunk

token = word_tokenize(text)
tags = nltk.pos_tag(token)
chunk = ne_chunk(tags)
chunk
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     336             method = get_real_method(obj, self.print_method)
#     337             if method is not None:
# --> 338                 return method()
#     339             return None
#     340         else:
#
# /usr/local/lib/python3.6/dist-packages/nltk/tree.py in _repr_png_(self)
#     717         from nltk.draw.util import CanvasFrame
#     718         from nltk.internals import find_binary
# --> 719         _canvas_frame = CanvasFrame()
#     720         widget = tree_to_treesegment(_canvas_frame.canvas(), self)
#     721         _canvas_frame.add_widget(widget)
#
# /usr/local/lib/python3.6/dist-packages/nltk/draw/util.py in __init__(self, parent, **kw)
#    1651         # If no parent was given, set up a top-level window.
#    1652         if parent is None:
# -> 1653             self._parent = Tk()
#    1654             self._parent.title('NLTK')
#    1655             self._parent.bind('<Control-p>', lambda e: self.print_to_file())
#
# /usr/lib/python3.6/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable
# Tree('S', [Tree('PERSON', [('Data', 'NNP'), ('Analyst', 'NNP')]), ('-', ':'), Tree('PERSON', [('Geotab', 'NNP'), ('Hiring', 'NNP'), ('Manager', 'NNP')]), ('-', ':'), Tree('PERSON', [('James', 'NNP'), ('Brown', 'NNP'), ('Location', 'NNP')]), ('-', ':'), Tree('GPE', [('Oakville', 'NN')]), ('Who', 'IN'), ('we', 'PRP'), ('are', 'VBP'), (':', ':'), Tree('PERSON', [('Geotab', 'NNP')]), ('is', 'VBZ'), ('a', 'DT'), ('global', 'JJ'), ('leader', 'NN'), ('in', 'IN'), Tree('ORGANIZATION', [('IoT', 'NNP')]), ('and', 'CC'), ('connected', 'VBN'), ('transportation', 'NN'), ('and', 'CC'), ('certified', 'JJ'), ('“', 'NNP'), ('Great', 'NNP'), ('Place', 'NNP'), ('to', 'TO'), ('Work.', 'NNP'), ('”', 'NNP'), ('We', 'PRP'), ('are', 'VBP'), ('a', 'DT'), ('company', 'NN'), ('of', 'IN'), ('diverse', 'NN'), ('and', 'CC'), ('talented', 'JJ'), ('individuals', 'NNS'), ('who', 'WP'), ('work', 'VBP'), ('together', 'RB'), ('to', 'TO'), ('help', 'VB'), ('businesses', 'NNS'), ('grow', 'VB'), ('and', 'CC'), ('succeed', 'VB'), (',', ','), ('and', 'CC'), ('increase', 'VB'), ('the', 'DT'), ('safety', 'NN'), ('and', 'CC'), ('sustainability', 'NN'), ('of', 'IN'), ('our', 'PRP$'), ('communities', 'NNS'), ('.', '.'), Tree('PERSON', [('Geotab', 'NNP')]), ('is', 'VBZ'), ('advancing', 'VBG'), ('security', 'NN'), (',', ','), ('connecting', 'VBG'), ('commercial', 'JJ'), ('vehicles', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('internet', 'NN'), ('and', 'CC'), ('providing', 'VBG'), ('web-based', 'JJ'), ('analytics', 'NNS'), ('to', 'TO'), ('help', 'VB'), ('customers', 'NNS'), ('better', 'RBR'), ('manage', 'VBP'), ('their', 'PRP$'), ('fleets', 'NNS'), ('.', '.'), Tree('PERSON', [('Geotab', 'NNP')]), ('’', 'NNP'), ('s', 'VBD'), ('open', 'JJ'), ('platform', 'NN'), ('and', 'CC'), Tree('PERSON', [('Marketplace', 'NNP')]), (',', ','), ('offering', 'VBG'), ('hundreds', 'NNS'), ('of', 'IN'), ('third-party', 'JJ'), ('solution', 'NN'), ('options', 'NNS'), (',', ','), ('allows', 'VBZ'), ('both', 'DT'), ('small', 'JJ'), ('and', 'CC'), ('large', 'JJ'), ('businesses', 'NNS'), ('to', 'TO'), ('automate', 'VB'), ('operations', 'NNS'), ('by', 'IN'), ('integrating', 'VBG'), ('vehicle', 'NN'), ('data', 'NNS'), ('with', 'IN'), ('their', 'PRP$'), ('other', 'JJ'), ('data', 'NNS'), ('assets', 'NNS'), ('.', '.'), ('Processing', 'VBG'), ('billions', 'NNS'), ('of', 'IN'), ('data', 'NNS'), ('points', 'NNS'), ('a', 'DT'), ('day', 'NN'), (',', ','), Tree('PERSON', [('Geotab', 'NNP')]), ('leverages', 'VBZ'), ('data', 'NNS'), ('analytics', 'NNS'), ('and', 'CC'), ('machine', 'NN'), ('learning', 'NN'), ('to', 'TO'), ('improve', 'VB'), ('productivity', 'NN'), (',', ','), ('optimize', 'JJ'), ('fleets', 'NNS'), ('through', 'IN'), ('the', 'DT'), ('reduction', 'NN'), ('of', 'IN'), ('fuel', 'NN'), ('consumption', 'NN'), (',', ','), ('enhance', 'NN'), ('driver', 'NN'), ('safety', 'NN'), ('and', 'CC'), ('achieve', 'VB'), ('strong', 'JJ'), ('compliance', 'NN'), ('to', 'TO'), ('regulatory', 'JJ'), ('changes', 'NNS'), ('.', '.'), ('Our', 'PRP$'), ('team', 'NN'), ('is', 'VBZ'), ('growing', 'VBG'), ('and', 'CC'), ('we', 'PRP'), ('’', 'VBP'), ('re', 'JJ'), ('looking', 'VBG'), ('for', 'IN'), ('people', 'NNS'), ('who', 'WP'), ('follow', 'VBP'), ('their', 'PRP$'), ('passion', 'NN'), (',', ','), ('think', 'VBP'), ('differently', 'RB'), ('and', 'CC'), ('want', 'VBP'), ('to', 'TO'), ('make', 'VB'), ('an', 'DT'), ('impact', 'NN'), ('.', '.'), ('Join', 'VB'), ('us', 'PRP'), ('for', 'IN'), ('a', 'DT'), ('fulfilling', 'JJ'), ('career', 'NN'), ('with', 'IN'), ('opportunities', 'NNS'), ('to', 'TO'), ('innovate', 'VB'), (',', ','), ('great', 'JJ'), ('benefits', 'NNS'), (',', ','), ('and', 'CC'), ('our', 'PRP$'), ('fun', 'NN'), ('and', 'CC'), ('inclusive', 'JJ'), ('work', 'NN'), ('culture', 'NN'), ('.', '.'), ('Reach', 'VB'), ('your', 'PRP$'), ('full', 'JJ'), ('potential', 'NN'), ('with', 'IN'), Tree('PERSON', [('Geotab', 'NNP')]), ('.', '.'), ('To', 'TO'), ('see', 'VB'), ('what', 'WP'), ('it', 'PRP'), ('’', 'VBD'), ('s', 'NNS'), ('like', 'IN ...

# %% [markdown]
# Chunking: Chunking means picking up individual pieces of information and grouping them into bigger pieces. In the context of NLP and text mining, chunking means a grouping of words or tokens into chunks.

# %%
# Input the data (Open a text file for reading)
text = open('JD.txt', 'r')

# Store content in a variable
text = text.read()

token = word_tokenize(text)
tags = nltk.pos_tag(token)

reg = "NP: {<DT>?<JJ>*<NN>}" 
a = nltk.RegexpParser(reg)
result = a.parse(tags)
print(result)
# Out:
# (S
#   Data/NNP
#   Analyst/NNP
#   -/:
#   Geotab/NNP
#   Hiring/NNP
#   Manager/NNP
#   -/:
#   James/NNP
#   Brown/NNP
#   Location/NNP
#   -/:
#   (NP Oakville/NN)
#   Who/IN
#   we/PRP
#   are/VBP
#   :/:
#   Geotab/NNP
#   is/VBZ
#   (NP a/DT global/JJ leader/NN)
#   in/IN
#   IoT/NNP
#   and/CC
#   connected/VBN
#   (NP transportation/NN)
#   and/CC
#   certified/JJ
#   “/NNP
#   Great/NNP
#   Place/NNP
#   to/TO
#   Work./NNP
#   ”/NNP
#   We/PRP
#   are/VBP
#   (NP a/DT company/NN)
#   of/IN
#   (NP diverse/NN)
#   and/CC
#   talented/JJ
#   individuals/NNS
#   who/WP
#   work/VBP
#   together/RB
#   to/TO
#   help/VB
#   businesses/NNS
#   grow/VB
#   and/CC
#   succeed/VB
#   ,/,
#   and/CC
#   increase/VB
#   (NP the/DT safety/NN)
#   and/CC
#   (NP sustainability/NN)
#   of/IN
#   our/PRP$
#   communities/NNS
#   ./.
#   Geotab/NNP
#   is/VBZ
#   advancing/VBG
#   (NP security/NN)
#   ,/,
#   connecting/VBG
#   commercial/JJ
#   vehicles/NNS
#   to/TO
#   (NP the/DT internet/NN)
#   and/CC
#   providing/VBG
#   web-based/JJ
#   analytics/NNS
#   to/TO
#   help/VB
#   customers/NNS
#   better/RBR
#   manage/VBP
#   their/PRP$
#   fleets/NNS
#   ./.
#   Geotab/NNP
#   ’/NNP
#   s/VBD
#   (NP open/JJ platform/NN)
#   and/CC
#   Marketplace/NNP
#   ,/,
#   offering/VBG
#   hundreds/NNS
#   of/IN
#   (NP third-party/JJ solution/NN)
#   options/NNS
#   ,/,
#   allows/VBZ
#   both/DT
#   small/JJ
#   and/CC
#   large/JJ
#   businesses/NNS
#   to/TO
#   automate/VB
#   operations/NNS
#   by/IN
#   integrating/VBG
#   (NP vehicle/NN)
#   data/NNS
#   with/IN
#   their/PRP$
#   other/JJ
#   data/NNS
#   assets/NNS
#   ./.
#   Processing/VBG
#   billions/NNS
#   of/IN
#   data/NNS
#   points/NNS
#   (NP a/DT day/NN)
#   ,/,
#   Geotab/NNP
#   leverages/VBZ
#   data/NNS
#   analytics/NNS
#   and/CC
#   (NP machine/NN)
#   (NP learning/NN)
#   to/TO
#   improve/VB
#   (NP productivity/NN)
#   ,/,
#   optimize/JJ
#   fleets/NNS
#   through/IN
#   (NP the/DT reduction/NN)
#   of/IN
#   (NP fuel/NN)
#   (NP consumption/NN)
#   ,/,
#   (NP enhance/NN)
#   (NP driver/NN)
#   (NP safety/NN)
#   and/CC
#   achieve/VB
#   (NP strong/JJ compliance/NN)
#   to/TO
#   regulatory/JJ
#   changes/NNS
#   ./.
#   Our/PRP$
#   (NP team/NN)
#   is/VBZ
#   growing/VBG
#   and/CC
#   we/PRP
#   ’/VBP
#   re/JJ
#   looking/VBG
#   for/IN
#   people/NNS
#   who/WP
#   follow/VBP
#   their/PRP$
#   (NP passion/NN)
#   ,/,
#   think/VBP
#   differently/RB
#   and/CC
#   want/VBP
#   to/TO
#   make/VB
#   (NP an/DT impact/NN)
#   ./.
#   Join/VB
#   us/PRP
#   for/IN
#   (NP a/DT fulfilling/JJ career/NN)
#   with/IN
#   opportunities/NNS
#   to/TO
#   innovate/VB
#   ,/,
#   great/JJ
#   benefits/NNS
#   ,/,
#   and/CC
#   our/PRP$
#   (NP fun/NN)
#   and/CC
#   (NP inclusive/JJ work/NN)
#   (NP culture/NN)
#   ./.
#   Reach/VB
#   your/PRP$
#   (NP full/JJ potential/NN)
#   with/IN
#   Geotab/NNP
#   ./.
#   To/TO
#   see/VB
#   what/WP
#   it/PRP
#   ’/VBD
#   s/NNS
#   like/IN
#   to/TO
#   be/VB
#   a/DT
#   Geotabber/NNP
#   ,/,
#   follow/VBP
#   us/PRP
#   @/JJ
#   InsideGeotab/NNP
#   on/IN
#   Instagram/NNP
#   ,/,
#   Twitter/NNP
#   or/CC
#   Facebook/NNP
#   ./.
#   Who/WP
#   we/PRP
#   are/VBP
#   looking/VBG
#   for/IN
#   :/:
#   We/PRP
#   are/VBP
#   looking/VBG
#   for/IN
#   Data/NNP
#   Analysts/NNS
#   who/WP
#   can/MD
#   help/VB
#   us/PRP
#   discover/VB
#   (NP value/NN)
#   out/IN
#   of/IN
#   our/PRP$
#   rich/JJ
#   and/CC
#   large/JJ
#   datasets/NNS
#   ./.
#   Our/PRP$
#   (NP ideal/JJ team/NN)
#   (NP member/NN)
#   will/MD
#   have/VB
#   the/DT
#   mathematical/JJ
#   and/CC
#   (NP statistical/JJ expertise/NN)
#   you/PRP
#   ’/VBP
#   d/JJ
#   expect/VBP
#   ,/,
#   but/CC
#   (NP a/DT natural/JJ curiosity/NN)
#   and/CC
#   (NP creative/JJ mind/NN)
#   that/WDT
#   ’/VBZ
#   s/MD
#   not/RB
#   so/RB
#   easy/JJ
#   to/TO
#   find/VB
#   ./.
#   As/IN
#   you/PRP
#   mine/VBP
#   ,/,
#   interpret/JJ
#   and/CC
#   clean/JJ
#   our/PRP$
#   data/NNS
#   ,/,
#   we/PRP
#   will/MD
#   rely/VB
#   on/IN
#   you/PRP
#   to/TO
#   ask/VB
#   questions/NNS
#   ,/,
#   connect/VBP
#   the/DT
#   dots/NNS
#   and/CC
#   uncover/JJ
#   opportunities/NNS
#   that/WDT
#   lie/VBP
#   hidden/VBN
#   within/IN
#   ,/,
#   all/DT
#   with/IN
#   (NP the/DT ultimate/JJ goal/NN)
#   of/IN
#   realizing/VBG
#   (NP the/DT data/NN)
#   (NP ’/NN)
#   s/CC
#   (NP full/JJ potential/NN)
#   ./.
#   What/WP
#   are/VBP
#   the/DT
#   details/NNS
#   of/IN
#   (NP this/DT position/NN)
#   :/:
#   The/DT
#   Data/NNP
#   Analyst/NNP
#   will/MD
#   join/VB
#   RMA/NNP
#   (NP team/NN)
#   under/IN
#   Operations/NNP
#   and/CC
#   will/MD
#   analyze/VB
#   well-defined/JJ
#   sets/NNS
#   of/IN
#   data/NNS
#   using/VBG
#   (NP a/DT variety/NN)
#   of/IN
#   different/JJ
#   tools/NNS
#   to/TO
#   answer/VB
#   (NP tangible/JJ business/NN)
#   needs/NNS
#   and/CC
#   find/VB
#   meaningful/JJ
#   insights/NNS
#   ./.
#   (NP The/DT position/NN)
#   will/MD
#   understand/VB
#   how/WRB
#   internal/JJ
#   departments/NNS
#   can/MD
#   directly/RB
#   benefit/VB
#   from/IN
#   (NP the/DT analysis/NN)
#   and/CC
#   develop/VB
#   products/NNS
#   from/IN
#   these/DT
#   results/NNS
#   ./.
#   (NP The/DT position/NN)
#   works/VBZ
#   closely/RB
#   with/IN
#   Data/NNP
#   professionals/NNS
#   within/IN
#   the/DT
#   Data/NNP
#   &/CC
#   Analytics/NNP
#   Teams/NNP
#   ./.
#   Duties/NNS
#   and/CC
#   Tasks/Essential/JJ
#   Functions/NNS
#   :/:
#   Examine/NNP
#   large/JJ
#   data/NNS
#   sets/NNS
#   to/TO
#   identify/VB
#   trends/NNS
#   ,/,
#   develop/VB
#   charts/NNS
#   ,/,
#   and/CC
#   creative/JJ
#   visual/JJ
#   presentations/NNS
#   to/TO
#   help/VB
#   businesses/NNS
#   make/VB
#   more/JJR
#   strategic/JJ
#   decisions/NNS
#   ./.
#   Maintain/NNP
#   data/NNS
#   systems/NNS
#   and/CC
#   databases/NNS
#   ./.
#   Utilize/VB
#   statistical/JJ
#   tools/NNS
#   to/TO
#   interpret/VB
#   data/NNS
#   sets/NNS
#   and/CC
#   prepare/VB
#   reports/NNS
#   that/IN
#   effectively/RB
#   communicate/VB
#   trends/NNS
#   ,/,
#   patterns/NNS
#   ,/,
#   and/CC
#   predictions/NNS
#   based/VBN
#   on/IN
#   relevant/JJ
#   findings/NNS
#   ./.
#   Write/NNP
#   SQL/NNP
#   queries/NNS
#   to/TO
#   find/VB
#   answers/NNS
#   to/TO
#   (NP complex/JJ business/NN)
#   questions/NNS
#   ./.
#   Identify/VB
#   any/DT
#   data/NNS
#   (NP quality/NN)
#   issues/NNS
#   and/CC
#   partialities/NNS
#   in/IN
#   data/NNS
#   (NP acquisition/NN)
#   ./.
#   Coordinate/NNP
#   with/IN
#   (NP the/DT engineering/NN)
#   (NP team/NN)
#   to/TO
#   gather/VB
#   incremental/JJ
#   new/JJ
#   data/NNS
#   ./.
#   (NP Process/NN)
#   ,/,
#   (NP cleanse/NN)
#   and/CC
#   verify/VB
#   (NP the/DT integrity/NN)
#   of/IN
#   data/NNS
#   used/VBN
#   for/IN
#   (NP analysis/NN)
#   ./.
#   Use/NNP
#   (NP data/NN)
#   (NP mining/NN)
#   ,/,
#   (NP model/NN)
#   (NP building/NN)
#   ,/,
#   and/CC
#   other/JJ
#   analytical/JJ
#   techniques/NNS
#   to/TO
#   support/VB
#   internal/JJ
#   initiatives/NNS
#   ./.
#   Assist/VB
#   the/DT
#   internal/JJ
#   technical/JJ
#   departments/NNS
#   by/IN
#   providing/VBG
#   meaningful/JJ
#   insight/JJ
#   using/VBG
#   datasets/NNS
#   ./.
#   (NP Work/NN)
#   with/IN
#   data/NNS
#   scientists/NNS
#   and/CC
#   (NP leverage/NN)
#   (NP machine/NN)
#   learning/VBG
#   models/NNS
#   that/WDT
#   have/VBP
#   been/VBN
#   developed/VBN
#   against/IN
#   Geotab/NNP
#   's/POS
#   big/JJ
#   data/NNS
#   (NP environment/NN)
#   ./.
#   Experience/Skills/NNS
#   Required/VBN
#   :/:
#   0-5/JJ
#   years/NNS
#   experience/RB
#   as/IN
#   a/DT
#   Data/NNP
#   Analyst/NNP
#   or/CC
#   (NP a/DT similar/JJ role/NN)
#   ./.
#   3-5/JJ
#   years/NNS
#   (NP experience/NN)
#   with/IN
#   SQL/NNP
#   ./.
#   3-5/CD
#   years/NNS
#   (NP experience/NN)
#   with/IN
#   data/NNS
#   (NP science/NN)
#   tools/NNS
#   (/(
#   e.g/JJ
#   Python/NNP
#   ,/,
#   Pandas/NNP
#   ,/,
#   NumPy/NNP
#   )/)
#   ./.
#   Post-secondary/JJ
#   Degree/Diploma/NNP
#   (NP specialization/NN)
#   in/IN
#   Computer/NNP
#   Science/NNP
#   ,/,
#   Software/NNP
#   Engineering/NNP
#   ,/,
#   Science/NNP
#   ,/,
#   Mathematics/NNP
#   or/CC
#   (NP a/DT related/JJ field/NN)
#   ./.
#   (NP Experience/NN)
#   working/VBG
#   with/IN
#   big/JJ
#   data/NNS
#   and/CC
#   (NP an/DT understanding/NN)
#   of/IN
#   techniques/NNS
#   used/VBN
#   to/TO
#   extract/VB
#   (NP value/NN)
#   out/IN
#   of/IN
#   very/RB
#   large/JJ
#   datasets/NNS
#   ./.
#   (NP Experience/NN)
#   working/VBG
#   closely/RB
#   with/IN
#   (NP business/NN)
#   analysts/NNS
#   to/TO
#   arrive/VB
#   at/IN
#   data/NNS
#   solutions/NNS
#   ./.
#   (NP Experience/NN)
#   with/IN
#   (NP database/NN)
#   (NP design/NN)
#   and/CC
#   writing/VBG
#   queries/NNS
#   ./.
#   (NP Familiarity/NN)
#   with/IN
#   (NP machine/NN)
#   learning/VBG
#   concepts/NNS
#   is/VBZ
#   (NP an/DT asset/NN)
#   ./.
#   (NP Familiarity/NN)
#   with/IN
#   Scikit-learn/NNP
#   ,/,
#   Tensorflow/NNP
#   is/VBZ
#   (NP an/DT asset/NN)
#   ./.
#   Why/WRB
#   (NP job/NN)
#   seekers/NNS
#   choose/VBP
#   Geotab/NNP
#   :/:
#   (NP Work/NN)
#   from/IN
#   (NP home/NN)
#   and/CC
#   (NP flex/JJ work/NN)
#   arrangements/NNS
#   Baby/NNP
#   bonus/VBD
#   Home/NNP
#   (NP office/NN)
#   (NP reimbursement/NN)
#   (NP program/NN)
#   Online/NNP
#   (NP learning/NN)
#   and/CC
#   (NP networking/NN)
#   opportunities/NNS
#   Electric/NNP
#   (NP vehicle/NN)
#   (NP purchase/NN)
#   (NP incentive/JJ program/NN)
#   Competitive/NNP
#   medical/JJ
#   and/CC
#   dental/JJ
#   benefits/NNS
#   (/(
#   full-time/JJ
#   employees/NNS
#   only/RB
#   )/)
#   Retirement/NNP
#   savings/NNS
#   (NP program/NN)
#   (/(
#   full-time/JJ
#   employees/NNS
#   only/RB
#   )/)
#   Our/PRP$
#   Core/JJ
#   Values/NNS
#   :/:
#   At/IN
#   Geotab/NNP
#   ,/,
#   we/PRP
#   understand/VBP
#   that/IN
#   (NP the/DT world/NN)
#   is/VBZ
#   always/RB
#   changing/VBG
#   and/CC
#   that/IN
#   we/PRP
#   need/VBP
#   to/TO
#   change/VB
#   with/IN
#   it/PRP
#   ./.
#   Geotab/NNP
#   has/VBZ
#   adopted/VBN
#   (NP a/DT hybrid/JJ model/NN)
#   for/IN
#   working/VBG
#   ,/,
#   including/VBG
#   (NP a/DT flexible/JJ work/NN)
#   from/IN
#   (NP home/NN)
#   (NP program/NN)
#   ,/,
#   with/IN
#   (NP the/DT opportunity/NN)
#   to/TO
#   work/VB
#   in/IN
#   our/PRP$
#   safe/JJ
#   ,/,
#   clean/JJ
#   offices/NNS
#   ./.
#   Remote/NNP
#   (NP work/NN)
#   is/VBZ
#   supported/VBN
#   with/IN
#   cloud-based/JJ
#   applications/NNS
#   ,/,
#   (NP collaboration/NN)
#   tools/NNS
#   and/CC
#   (NP asynchronous/JJ working/NN)
#   ./.
#   (NP The/DT health/NN)
#   and/CC
#   (NP safety/NN)
#   of/IN
#   employees/NNS
#   are/VBP
#   (NP a/DT top/JJ priority/NN)
#   ./.
#   We/PRP
#   encourage/VBP
#   (NP work-life/JJ balance/NN)
#   and/CC
#   keep/VB
#   the/DT
#   Geotab/NNP
#   (NP culture/NN)
#   going/VBG
#   strong/JJ
#   with/IN
#   online/JJ
#   social/JJ
#   events/NNS
#   ,/,
#   (NP chat/NN)
#   rooms/NNS
#   and/CC
#   gatherings/NNS
#   ./.
#   Join/VB
#   us/PRP
#   and/CC
#   help/VB
#   reshape/VB
#   (NP the/DT future/NN)
#   of/IN
#   (NP technology/NN)
#   !/.
#   Data/NNP
#   Analyst/NNP
#   -/:
#   Dialpad/NNP
#   Hiring/NNP
#   Manager/NNP
#   -/:
#   Chris/NNP
#   Yellow/NNP
#   Location/NNP
#   -/:
#   Toronto/NNP
#   Dialpad/NNP
#   is/VBZ
#   the/DT
#   most/RBS
#   (NP modern/JJ business/NN)
#   communications/NNS
#   (NP company/NN)
#   in/IN
#   (NP the/DT industry/NN)
#   ./.
#   Our/PRP$
#   products/NNS
#   range/VBP
#   from/IN
#   (NP conference/NN)
#   calling/VBG
#   ,/,
#   to/TO
#   (NP phone/NN)
#   systems/NNS
#   to/TO
#   contact/VB
#   center/JJ
#   solutions/NNS
#   that/WDT
#   are/VBP
#   all/DT
#   built/VBN
#   with/IN
#   (NP the/DT end-user/NN)
#   in/IN
#   (NP mind/NN)
#   ./.
#   We/PRP
#   allow/VBP
#   workers/NNS
#   to/TO
#   be/VB
#   productive/JJ
#   from/IN
#   anywhere/RB
#   on/IN
#   (NP any/DT device/NN)
#   and/CC
#   have/VBP
#   moved/VBN
#   all/PDT
#   (NP the/DT power/NN)
#   of/IN
#   (NP an/DT on-premise/JJ phone/NN)
#   (NP system/NN)
#   or/CC
#   (NP contact/NN)
#   (NP center/NN)
#   to/TO
#   (NP the/DT cloud/NN)
#   to/TO
#   be/VB
#   accessed/VBN
#   and/CC
#   used/VBN
#   by/IN
#   modern/JJ
#   workers/NNS
#   in/IN
#   (NP today/NN)
#   's/POS
#   (NP Work/NN)
#   from/IN
#   Anywhere/NNP
#   (NP environment/NN)
#   ./.
#   Who/IN
#   We/PRP
#   Are/VBP
#   At/IN
#   Dialpad/NNP
#   ,/,
#   (NP work/NN)
#   is/VBZ
#   n't/RB
#   (NP a/DT place/NN)
#   you/PRP
#   go/VBP
#   ,/,
#   it/PRP
#   's/VBZ
#   (NP a/DT thing/NN)
#   you/PRP
#   do/VBP
#   ./.
#   With/IN
#   offices/NNS
#   in/IN
#   San/NNP
#   Francisco/NNP
#   ,/,
#   San/NNP
#   Ramon/NNP
#   ,/,
#   Austin/NNP
#   ,/,
#   Raleigh/NNP
#   ,/,
#   Vancouver/NNP
#   ,/,
#   Waterloo/NNP
#   ,/,
#   Tokyo/NNP
#   ,/,
#   London/NNP
#   ,/,
#   Sydney/NNP
#   and/CC
#   Bangalore/NNP
#   ,/,
#   we/PRP
#   truly/RB
#   believe/VBP
#   in/IN
#   finding/VBG
#   the/DT
#   best/JJS
#   (NP talent/NN)
#   everywhere/RB
#   ./.
#   We/PRP
#   also/RB
#   embrace/VBP
#   (NP the/DT Work/NN)
#   from/IN
#   Home/NNP
#   (NP movement/NN)
#   and/CC
#   are/VBP
#   just/RB
#   as/IN
#   happy/JJ
#   hiring/VBG
#   (NP great/JJ talent/NN)
#   from/IN
#   anywhere/RB
#   if/IN
#   they/PRP
#   choose/VBP
#   to/TO
#   work/VB
#   from/IN
#   (NP home/NN)
#   rather/RB
#   than/IN
#   in/IN
#   (NP an/DT office/NN)
#   ./.
#   With/IN
#   over/IN
#   $/$
#   220/CD
#   million/CD
#   in/IN
#   (NP funding/NN)
#   from/IN
#   OMERS/NNP
#   Growth/NNP
#   Equity/NNP
#   ,/,
#   ICONIQ/NNP
#   Capital/NNP
#   ,/,
#   GV/NNP
#   ,/,
#   Andreessen/NNP
#   Horowitz/NNP
#   ,/,
#   Felicis/NNP
#   Ventures/NNP
#   ,/,
#   Work-Bench/NNP
#   ,/,
#   Scale/NNP
#   Ventures/NNP
#   and/CC
#   other/JJ
#   top/JJ
#   VCs/NNP
#   ,/,
#   Dialpad/NNP
#   attracts/VBZ
#   top/JJ
#   engineers/NNS
#   from/IN
#   companies/NNS
#   like/IN
#   Microsoft/NNP
#   and/CC
#   Google/NNP
#   ,/,
#   and/CC
#   (NP every/DT member/NN)
#   of/IN
#   our/PRP$
#   (NP team/NN)
#   plays/VBZ
#   (NP an/DT essential/JJ role/NN)
#   in/IN
#   creating/VBG
#   dynamic/JJ
#   products/NNS
#   that/WDT
#   enable/JJ
#   workers/NNS
#   to/TO
#   be/VB
#   productive/JJ
#   from/IN
#   anywhere/RB
#   !/.
#   About/IN
#   (NP the/DT Role/NN)
#   :/:
#   (NP The/DT machine/NN)
#   (NP learning/NN)
#   (NP team/NN)
#   is/VBZ
#   responsible/JJ
#   for/IN
#   building/VBG
#   all/PDT
#   the/DT
#   models/NNS
#   used/VBN
#   to/TO
#   deliver/VB
#   our/PRP$
#   Voice/NNP
#   Intelligence/NNP
#   AI/NNP
#   (NP technology/NN)
#   ./.
#   We/PRP
#   are/VBP
#   looking/VBG
#   for/IN
#   a/DT
#   Data/NNP
#   Analyst/NNP
#   who/WP
#   will/MD
#   support/VB
#   our/PRP$
#   Data/NNP
#   Science/NNP
#   ,/,
#   Speech/NNP
#   Recognition/NNP
#   ,/,
#   and/CC
#   Data/NNP
#   Engineering/NNP
#   teams/NNS
#   to/TO
#   help/VB
#   deliver/VB
#   valuable/JJ
#   insights/NNS
#   to/TO
#   customers/NNS
#   ./.
#   (NP The/DT ideal/JJ person/NN)
#   has/VBZ
#   (NP excellent/JJ critical/JJ thinking/NN)
#   skills/NNS
#   ,/,
#   (NP attention/NN)
#   to/TO
#   detail/VB
#   ,/,
#   can/MD
#   handle/VB
#   large/JJ
#   data/NNS
#   sets/NNS
#   ,/,
#   and/CC
#   can/MD
#   work/VB
#   in/IN
#   (NP the/DT gap/NN)
#   between/IN
#   (NP business/NN)
#   stakeholders/NNS
#   and/CC
#   (NP speech/language/NN)
#   scientists/NNS
#   ./.
#   (NP The/DT data/NN)
#   (NP analyst/NN)
#   will/MD
#   work/VB
#   closely/RB
#   with/IN
#   the/DT
#   Speech/NNP
#   and/CC
#   Natural/NNP
#   Language/NNP
#   Processing/NNP
#   teams/NNS
#   to/TO
#   do/VB
#   (NP insightful/JJ analysis/NN)
#   across/IN
#   huge/JJ
#   collections/NNS
#   of/IN
#   conversations/NNS
#   to/TO
#   help/VB
#   identify/VB
#   trends/NNS
#   in/IN
#   our/PRP$
#   transcriptions/NNS
#   ,/,
#   how/WRB
#   we/PRP
#   can/MD
#   reduce/VB
#   (NP the/DT bias/NN)
#   in/IN
#   our/PRP$
#   ASR/NNP
#   systems/NNS
#   ,/,
#   and/CC
#   other/JJ
#   areas/NNS
#   where/WRB
#   we/PRP
#   can/MD
#   improve/VB
#   our/PRP$
#   (NP transcription/NN)
#   and/CC
#   (NP customer/NN)
#   (NP experience/NN)
#   ./.
#   (NP The/DT work/NN)
#   is/VBZ
#   (NP a/DT mix/NN)
#   of/IN
#   data/NNS
#   (NP exploration/NN)
#   ,/,
#   (NP hypothesis/NN)
#   (NP testing/NN)
#   ,/,
#   (NP database/NN)
#   (NP administration/NN)
#   ,/,
#   data/NNS
#   (NP analysis/NN)
#   ,/,
#   and/CC
#   (NP business/NN)
#   (NP intelligence/NN)
#   ./.
#   Ideally/RB
#   ,/,
#   you/PRP
#   have/VBP
#   experience/VBN
#   manipulating/VBG
#   large/JJ
#   data/NNS
#   sets/NNS
#   ,/,
#   have/VBP
#   (NP some/DT knowledge/NN)
#   of/IN
#   (NP machine/NN)
#   (NP learning/NN)
#   practices/NNS
#   and/CC
#   (NP data/NN)
#   requirements/NNS
#   ,/,
#   and/CC
#   are/VBP
#   comfortable/JJ
#   operating/VBG
#   in/IN
#   (NP an/DT agile/JJ environment/NN)
#   ./.
#   If/IN
#   you/PRP
#   're/VBP
#   inspired/VBN
#   by/IN
#   (NP innovation/NN)
#   and/CC
#   you/PRP
#   like/IN
#   working/VBG
#   with/IN
#   (NP a/DT smart/NN)
#   ,/,
#   talented/VBN
#   ,/,
#   generally/RB
#   (NP awesome/JJ team/NN)
#   ,/,
#   we/PRP
#   'd/MD
#   love/VB
#   to/TO
#   hear/VB
#   from/IN
#   you/PRP
#   !/.
#   Responsibilities/NNS
#   :/:
#   Ability/NNP
#   and/CC
#   (NP desire/NN)
#   to/TO
#   deeply/VB
#   understand/VB
#   our/PRP$
#   users/NNS
#   '/POS
#   (NP point/NN)
#   of/IN
#   (NP view/NN)
#   Ability/NNP
#   to/TO
#   work/VB
#   with/IN
#   scientists/NNS
#   ,/,
#   linguists/NNS
#   ,/,
#   and/CC
#   engineers/NNS
#   to/TO
#   take/VB
#   and/CC
#   generate/VB
#   interesting/JJ
#   questions/NNS
#   and/CC
#   turn/VB
#   them/PRP
#   into/IN
#   interesting/VBG
#   stories/NNS
#   told/VBD
#   with/IN
#   data/NNS
#   Given/VBN
#   a/DT
#   use-case/JJ
#   be/VB
#   able/JJ
#   to/TO
#   recommend/VB
#   and/CC
#   (NP source/NN)
#   the/DT
#   required/VBN
#   data/NNS
#   independently/RB
#   Build/NNP
#   and/CC
#   maintain/VB
#   views/NNS
#   that/IN
#   simplify/JJ
#   queries/NNS
#   for/IN
#   the/DT
#   AI/NNP
#   (NP team/NN)
#   Start/NNP
#   with/IN
#   (NP an/DT ad/NN)
#   (NP hoc/NN)
#   (NP proof-of-concept/NN)
#   (/(
#   what/WP
#   does/VBZ
#   the/DT
#   data/NNS
#   tell/VBP
#   us/PRP
#   about/IN
#   (NP this/DT question/NN)
#   ?/.
#   )/)
#   then/RB
#   turn/VB
#   it/PRP
#   into/IN
#   (NP a/DT process/NN)
#   that/IN
#   we/PRP
#   can/MD
#   run/VB
#   on/IN
#   (NP a/DT regular/JJ basis/NN)
#   Requirements/NNS
#   :/:
#   3+/CD
#   years/NNS
#   of/IN
#   (NP experience/NN)
#   as/IN
#   (NP a/DT data/NN)
#   (NP analyst/NN)
#   or/CC
#   (NP similar/JJ quantitative/JJ role/NN)
#   ./.
#   (NP Excellent/JJ communicator/NN)
#   and/CC
#   listener/JJR
#   History/NNP
#   of/IN
#   delivering/VBG
#   impactful/JJ
#   insights/NNS
#   Excellent/NNP
#   (NP organizational/NN)
#   ,/,
#   analytical/JJ
#   ,/,
#   and/CC
#   (NP research/NN)
#   skills/NNS
#   Flexible/JJ
#   with/IN
#   (NP regard/NN)
#   to/TO
#   changing/VBG
#   priorities/NNS
#   &/CC
#   (NP business/NN)
#   needs/NNS
#   ./.
#   Advanced/NNP
#   in/IN
#   SQL/NNP
#   Sound/NNP
#   statistical/JJ
#   skills/NNS
#   ,/,
#   (NP ability/NN)
#   to/TO
#   review/VB
#   experimental/JJ
#   designs/NNS
#   ,/,
#   and/CC
#   (NP test/NN)
#   for/IN
#   (NP significance/NN)
#   ./.
#   (NP Coursework/NN)
#   in/IN
#   Mathematics/NNP
#   and/CC
#   Statistics/NNPS
#   Bonus/NNP
#   points/NNS
#   for/IN
#   :/:
#   (NP Experience/NN)
#   with/IN
#   Python/NNP
#   (/(
#   or/CC
#   (NP another/DT scripting/JJ language/NN)
#   )/)
#   is/VBZ
#   (NP a/DT plus/JJ Expertise/NN)
#   or/CC
#   (NP experience/NN)
#   in/IN
#   Linguistics/NNP
#   ,/,
#   Natural/NNP
#   Language/NNP
#   Processing/NNP
#   or/CC
#   Speech/NNP
#   Recognition/NNP
#   Experience/NNP
#   with/IN
#   B2B/NNP
#   sales/NNS
#   and/CC
#   (NP support/NN)
#   scenarios/NNS
#   About/IN
#   Us/NNP
#   Joining/NNP
#   our/PRP$
#   (NP team/NN)
#   means/VBZ
#   collaborating/VBG
#   with/IN
#   people/NNS
#   that/WDT
#   are/VBP
#   n't/RB
#   just/RB
#   passionate/VB
#   about/IN
#   their/PRP$
#   (NP work/NN)
#   but/CC
#   about/IN
#   Argentine/NNP
#   (NP tango/NN)
#   ,/,
#   musicals/NNS
#   ,/,
#   (NP sushi/NN)
#   (NP burritos/NN)
#   ,/,
#   comic/JJ
#   books/NNS
#   -/:
#   you/PRP
#   name/VBP
#   it/PRP
#   ./.
#   Because/IN
#   if/IN
#   you/PRP
#   're/VBP
#   going/VBG
#   to/TO
#   redefine/VB
#   (NP the/DT status/NN)
#   (NP quo/NN)
#   ,/,
#   you/PRP
#   need/VBP
#   (NP a/DT group/NN)
#   of/IN
#   people/NNS
#   hungry/JJ
#   to/TO
#   do/VB
#   more/JJR
#   ,/,
#   to/TO
#   see/VB
#   more/JJR
#   ,/,
#   and/CC
#   be/VB
#   more/JJR
#   than/IN
#   where/WRB
#   they/PRP
#   started/VBD
#   ./.
#   There/EX
#   is/VBZ
#   (NP no/DT idea/NN)
#   too/RB
#   crazy/JJ
#   and/CC
#   (NP no/DT task/NN)
#   too/RB
#   (NP small/JJ —/NN)
#   we/PRP
#   work/VBP
#   together/RB
#   to/TO
#   make/VB
#   things/NNS
#   we/PRP
#   're/VBP
#   proud/JJ
#   of/IN
#   ./.
#   Compensation/NNP
#   &/CC
#   Equity/NNP
#   Teamwork/NNP
#   makes/VBZ
#   (NP the/DT dream/NN)
#   (NP work/NN)
#   ./.
#   We/PRP
#   recognize/VBP
#   that/IN
#   our/PRP$
#   (NP dedicated/JJ team/NN)
#   members/NNS
#   are/VBP
#   what/WP
#   make/VBP
#   us/PRP
#   successful/JJ
#   ./.
#   That/DT
#   's/VBZ
#   why/WRB
#   we/PRP
#   offer/VBP
#   competitive/JJ
#   salaries/NNS
#   in/IN
#   (NP addition/NN)
#   to/TO
#   (NP stock/NN)
#   options/NNS
#   ./.
#   Healthcare/NNP
#   (NP An/DT apple/NN)
#   (NP a/DT day/NN)
#   keeps/VBZ
#   (NP the/DT doctor/NN)
#   away/RB
#   -/:
#   and/CC
#   it/PRP
#   does/VBZ
#   n't/RB
#   hurt/VB
#   that/IN
#   we/PRP
#   offer/VBP
#   100/CD
#   (NP %/NN)
#   paid/VBN
#   medical/JJ
#   ,/,
#   dental/JJ
#   ,/,
#   and/CC
#   (NP vision/NN)
#   plans/NNS
#   for/IN
#   all/DT
#   employees/NNS
#   ./.
#   Reimbursements/NNS
#   We/PRP
#   offer/VBP
#   (NP a/DT monthly/JJ stipend/NN)
#   to/TO
#   help/VB
#   cover/VB
#   your/PRP$
#   (NP cell/NN)
#   (NP phone/NN)
#   ,/,
#   (NP home/NN)
#   (NP internet/NN)
#   ,/,
#   and/CC
#   even/RB
#   (NP gym/JJ membership/NN)
#   costs/NNS
#   ./.
#   (NP Education/NN)
#   We/PRP
#   believe/VBP
#   in/IN
#   your/PRP$
#   (NP future/NN)
#   as/RB
#   much/RB
#   as/IN
#   you/PRP
#   do/VBP
#   !/.
#   That/DT
#   's/VBZ
#   why/WRB
#   we/PRP
#   offer/VBP
#   (NP a/DT yearly/JJ stipend/NN)
#   for/IN
#   (NP continued/JJ learning/NN)
#   and/CC
#   (NP education/NN)
#   expenses/NNS
#   ./.
#   Location/NNP
#   ,/,
#   Location/NNP
#   ,/,
#   Location/NNP
#   San/NNP
#   Francisco/NNP
#   </NNP
#   >/NNP
#   San/NNP
#   Ramon/NNP
#   </NNP
#   >/NNP
#   Austin/NNP
#   </NNP
#   >/NNP
#   Raleigh/NNP
#   </NNP
#   >/NNP
#   Vancouver/NNP
#   </NNP
#   >/NNP
#   Kitchener/NNP
#   </NNP
#   >/NNP
#   Tokyo/NNP
#   </NNP
#   >/NNP
#   New/NNP
#   York/NNP
#   </NNP
#   >/NNP
#   Bangalore/NNP
#   ./.
#   From/IN
#   (NP coast/NN)
#   to/TO
#   (NP coast/NN)
#   ,/,
#   our/PRP$
#   offices/NNS
#   are/VBP
#   nestled/VBN
#   in/IN
#   active/JJ
#   and/CC
#   growing/VBG
#   downtown/JJ
#   areas/NNS
#   Dialpad/NNP
#   is/VBZ
#   (NP an/DT equal/JJ opportunity/NN)
#   (NP employer/NN)
#   ;/:
#   we/PRP
#   believe/VBP
#   in/IN
#   creating/VBG
#   (NP a/DT community/NN)
#   of/IN
#   (NP inclusion/NN)
#   and/CC
#   (NP an/DT environment/NN)
#   free/JJ
#   from/IN
#   (NP discrimination/NN)
#   or/CC
#   (NP harassment/NN)
#   ./.
#   Geotab/NNP
#   encourages/VBZ
#   applications/NNS
#   from/IN
#   all/DT
#   qualified/VBN
#   candidates/NNS
#   ./.
#   Geotab/NNP
#   is/VBZ
#   committed/VBN
#   to/TO
#   accommodating/VBG
#   persons/NNS
#   with/IN
#   disabilities/NNS
#   throughout/IN
#   (NP the/DT interview/NN)
#   ,/,
#   (NP selection/NN)
#   and/CC
#   (NP employment/NN)
#   (NP process/NN)
#   ./.
#   If/IN
#   you/PRP
#   require/VBP
#   (NP accommodation/NN)
#   at/IN
#   (NP any/DT stage/NN)
#   of/IN
#   (NP the/DT application/NN)
#   (NP process/NN)
#   or/CC
#   want/VB
#   more/JJR
#   (NP information/NN)
#   about/IN
#   our/PRP$
#   (NP accommodation/NN)
#   policies/NNS
#   and/CC
#   practices/NNS
#   ,/,
#   please/VB
#   contact/VB
#   us/PRP
#   at/IN
#   careers/NNS
#   @/VBP
#   (NP geotab.com/NN)
#   ./.
#   Hiring/NNP
#   Manager/NNP
#   -/:
#   John/NNP
#   Water/NNP
#   Location/NNP
#   -/:
#   Winnipeg/NNP
#   ,/,
#   Canada/NNP
#   Data/NNP
#   Analyst/NNP
#   -/:
#   Wellington-Altus/JJ
#   Private/NNP
#   Wealth/NNP
#   -/:
#   Winnipeg/NNP
#   ,/,
#   MB/NNP
#   Wellington-Altus/NNP
#   is/VBZ
#   currently/RB
#   recruiting/VBG
#   for/IN
#   a/DT
#   Data/NNP
#   Analyst/NNP
#   (NP position/NN)
#   ./.
#   The/DT
#   Data/NNP
#   Analyst/NNP
#   will/MD
#   work/VB
#   with/IN
#   the/DT
#   Wellington/NNP
#   Labs/NNP
#   (NP team/NN)
#   to/TO
#   provide/VB
#   data/NNS
#   solutions/NNS
#   to/TO
#   (NP power/NN)
#   (NP business/NN)
#   applications/NNS
#   ./.
#   In/IN
#   (NP this/DT role/NN)
#   ,/,
#   you/PRP
#   will/MD
#   work/VB
#   on/IN
#   projects/NNS
#   in/IN
#   a/DT
#   growing/VBG
#   (NP organization/NN)
#   with/IN
#   opportunities/NNS
#   to/TO
#   address/VB
#   problems/NNS
#   needing/VBG
#   creative/JJ
#   solutions/NNS
#   and/CC
#   models/NNS
#   ./.
#   You/PRP
#   will/MD
#   be/VB
#   working/VBG
#   on/IN
#   bringing/VBG
#   together/RB
#   different/JJ
#   data/NNS
#   sets/NNS
#   from/IN
#   across/IN
#   locations/NNS
#   and/CC
#   modeling/VBG
#   data/NNS
#   to/TO
#   unlock/VB
#   actionable/JJ
#   insights/NNS
#   that/WDT
#   help/VBP
#   stakeholders/NNS
#   formulate/VB
#   and/CC
#   answer/VB
#   (NP business/NN)
#   questions/NNS
#   ./.
#   You/PRP
#   will/MD
#   collaborate/VB
#   closely/RB
#   with/IN
#   stakeholders/NNS
#   from/IN
#   technical/JJ
#   solutions/NNS
#   (NP engineering/NN)
#   ,/,
#   (NP product/NN)
#   programs/NNS
#   ,/,
#   (NP vendor/NN)
#   operations/NNS
#   ,/,
#   (NP support/NN)
#   operations/NNS
#   ,/,
#   and/CC
#   (NP support/NN)
#   (NP experience/NN)
#   teams/NNS
#   ./.
#   As/IN
#   a/DT
#   Data/NNP
#   Analyst/NNP
#   ,/,
#   you/PRP
#   will/MD
#   :/:
#   Provide/VB
#   (NP decision-making/JJ support/NN)
#   for/IN
#   key/JJ
#   projects/NNS
#   ,/,
#   and/CC
#   (NP research/NN)
#   new/JJ
#   ways/NNS
#   of/IN
#   modeling/VBG
#   data/NNS
#   to/TO
#   unlock/VB
#   actionable/JJ
#   insights/NNS
#   or/CC
#   improve/VB
#   processes/NNS
#   ./.
#   Write/NNP
#   and/CC
#   review/VB
#   technical/JJ
#   documents/NNS
#   ,/,
#   including/VBG
#   requirements/NNS
#   and/CC
#   (NP design/NN)
#   documents/NNS
#   for/IN
#   existing/VBG
#   and/CC
#   future/JJ
#   data/NNS
#   systems/NNS
#   ,/,
#   as/RB
#   well/RB
#   as/IN
#   data/NNS
#   standards/NNS
#   and/CC
#   policies/NNS
#   ./.
#   Partner/NNP
#   with/IN
#   non-technical/JJ
#   stakeholders/NNS
#   to/TO
#   understand/VB
#   their/PRP$
#   needs/NNS
#   ,/,
#   (NP help/NN)
#   frame/VB
#   (NP the/DT problem/NN)
#   by/IN
#   asking/VBG
#   the/DT
#   right/JJ
#   questions/NNS
#   ,/,
#   and/CC
#   (NP document/NN)
#   and/CC
#   (NP prioritize/NN)
#   requirements/NNS
#   ./.
#   Communicate/NNP
#   results/NNS
#   of/IN
#   (NP technical/JJ work/NN)
#   ./.
#   Design/NNP
#   ,/,
#   (NP write/NN)
#   ,/,
#   and/CC
#   (NP support/NN)
#   (NP extract/NN)
#   ,/,
#   (NP transform/NN)
#   ,/,
#   and/CC
#   (NP load/NN)
#   (/(
#   ETL/NNP
#   )/)
#   processes/VBZ
#   to/TO
#   automate/VB
#   data/NNS
#   (NP collection/NN)
#   and/CC
#   (NP manage/NN)
#   pipelines/NNS
#   ./.
#   Your/PRP$
#   (NP education/NN)
#   and/CC
#   qualifications/NNS
#   include/VBP
#   :/:
#   BS/NNP
#   (NP degree/NN)
#   in/IN
#   Information/NNP
#   Management/NNP
#   ,/,
#   Computer/NNP
#   Science/NNP
#   ,/,
#   Statistics/NNPS
#   or/CC
#   similar/JJ
#   ./.
#   (NP Experience/NN)
#   in/IN
#   AWS/NNP
#   (NP administration/NN)
#   ./.
#   3/CD
#   years/NNS
#   of/IN
#   (NP experience/NN)
#   in/IN
#   (NP an/DT analyst/NN)
#   or/CC
#   Data/NNP
#   Science/NNP
#   (NP role/NN)
#   ./.
#   Experience/NNP
#   using/VBG
#   SQL/NNP
#   to/TO
#   work/VB
#   with/IN
#   multiple/JJ
#   datasets/NNS
#   ./.
#   (NP Experience/NN)
#   designing/VBG
#   data/NNS
#   models/NNS
#   and/CC
#   (NP building/NN)
#   data/NNS
#   structures/NNS
#   ./.
#   (NP Experience/NN)
#   in/IN
#   (NP a/DT language/NN)
#   for/IN
#   (NP statistical/JJ computing/NN)
#   (/(
#   R/NNP
#   ,/,
#   Python/pandas/NNP
#   ,/,
#   Stata/NNP
#   ,/,
#   (NP etc./NN)
#   )/)
#   ./.
#   Conditions/NNS
#   of/IN
#   (NP Employment/NN)
#   :/:
#   (NP Must/NN)
#   be/VB
#   legally/RB
#   eligible/JJ
#   to/TO
#   work/VB
#   in/IN
#   Canada/NNP
#   A/NNP
#   (NP background/NN)
#   (NP check/NN)
#   ,/,
#   (NP satisfactory/NN)
#   to/TO
#   (NP the/DT employer/NN)
#   ,/,
#   may/MD
#   be/VB
#   required/VBN
#   of/IN
#   (NP the/DT successful/JJ applicant/JJ prior/NN)
#   to/TO
#   commencing/VBG
#   (NP employment/NN)
#   Wellington-Altus/JJ
#   Private/NNP
#   Wealth/NNP
#   is/VBZ
#   strongly/RB
#   committed/VBN
#   to/TO
#   (NP equity/NN)
#   and/CC
#   (NP diversity/NN)
#   within/IN
#   its/PRP$
#   (NP community/NN)
#   and/CC
#   welcomes/NNS
#   applications/NNS
#   from/IN
#   women/NNS
#   ,/,
#   racialized/JJ
#   persons/NNS
#   ,/,
#   Indigenous/NNP
#   peoples/NNS
#   ,/,
#   persons/NNS
#   with/IN
#   disabilities/NNS
#   ,/,
#   and/CC
#   persons/NNS
#   of/IN
#   all/DT
#   sexual/JJ
#   orientations/NNS
#   and/CC
#   genders/NNS
#   ./.
#   All/DT
#   qualified/JJ
#   individuals/NNS
#   who/WP
#   would/MD
#   contribute/VB
#   to/TO
#   (NP the/DT further/JJ diversification/NN)
#   of/IN
#   our/PRP$
#   (NP organization/NN)
#   are/VBP
#   encouraged/VBN
#   to/TO
#   apply/VB
#   ./.
#   If/IN
#   you/PRP
#   require/VBP
#   (NP accommodation/NN)
#   for/IN
#   (NP the/DT recruitment/NN)
#   (NP process/NN)
#   ,/,
#   please/VB
#   let/VB
#   us/PRP
#   know/VB
#   at/IN
#   (NP the/DT point/NN)
#   of/IN
#   (NP application/NN)
#   ./.)
